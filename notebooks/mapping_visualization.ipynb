# %%
from fastfusion.frontend.mapping import Mapping
from IPython.display import SVG

mapping = Mapping.from_yaml("test/mha.mapping.yaml", top_key="mapping")
display(SVG(mapping.render())) # pip3 install mermaid-py
# Show the mermaid graph
# Out:
# INFO        Loading yaml file test/mha.mapping.yaml
# INFO        Found top key mapping in test/mha.mapping.yaml
