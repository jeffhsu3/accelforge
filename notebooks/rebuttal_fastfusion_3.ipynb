# %%
import hashlib
import os
import pickle
from hwcomponents_cacti import CactiSRAM
from hwcomponents_library import AladdinAdder, AladdinMultiplier

from fastfusion.frontend.architecture import Memory
from fastfusion.frontend.specification import Specification
from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_sims
from fastfusion.mapper.simanneal.wrappers import join_sims

import copy
import time
from fastfusion import Specification
from fastfusion.mapper.FFM.exploration.metrics import Metrics
from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_sims
from fastfusion.mapper.FFM.joining.sim import SIM
from fastfusion.mapper.FFM.joining.simexplore import join_sims
import fastfusion.mapper.FFM.exploration.mapper_one_einsum as mapper_one_einsum

from fastfusion.mapper.FFM.exploration.mapping_filter_tags.ffmt import get_ffmt_tag
from fastfusion.mapper.FFM.exploration.mapping_filter_tags.onesplit import get_one_split_tag
from fastfusion.mapper.FFM.pareto import PartialMappings

# TODO: area is an alias for get_area
# TODO: Separate energy and area
# TODO: Move scaling into main hwcomponents repo
# TODO: Function that just returns the hwcomponents component
# TODO: Is all the initial right consolidation necessary?
# TODO: Datawidth calculation for energy

# TODO: Reference specific tensor names in constraints, even if those tensors are not in
# a particular Einsum. Also have the error mrssages for parsing errors list which Einsum
# failed. Einsums that aren't in the tensor should resolve to NotInThisEinsum(), which =
# nothing.

# TODO: Make a setting for the below two in the spec
# TODO: Generate pmappings one Einsum at a time. Once we've made compatibility, check it
# against the previously-generated compatibilities and stop if there's no match.
# TODO: Once the previous is done, also add a forward check. Once the compatibilities of
# a particular Einsum are generated, we can immediately check the previous Einsums.
# TODO: Make the mapping return an object that supports union operators and stuff

spec = Specification.from_yaml(
    f"architecture/four_level.arch.yaml",
    "workloads/mha_full.workload.yaml",
    "workloads/mha_full.renames.yaml",
)

adder = AladdinAdder(technology="7nm", width=16)
multiplier = AladdinMultiplier(technology="7nm", width=8)
mac_area = adder.get_area() + multiplier.get_area()

print(f"COMPUTE ENERGY / 8 ????????????")
print(f"COMPUTE ENERGY / 8 ????????????")
print(f"COMPUTE ENERGY / 8 ????????????")
print(f"COMPUTE ENERGY / 8 ????????????")
print(f"COMPUTE ENERGY / 8 ????????????")

def get_fused_mappings(
        spec: Specification, 
        n_pes,
        local_buffer_model,
        global_buffer_model,
        tagger=None, 
        # fuse=True,
        parameterization="",
        return_mappings=False,
    ) -> PartialMappings:
    cachekey = (n_pes, local_buffer_model.width, local_buffer_model.depth, global_buffer_model.width, global_buffer_model.depth, parameterization)
    fname = parameterization + " " + hashlib.md5(str(cachekey).encode()).hexdigest()
    if os.path.exists(f"cache/{fname}.pkl"):
        print(f"Loading from cache: {fname}")
        mappings = pickle.load(open(f"cache/{fname}.pkl", "rb"))
        if return_mappings:
            return mappings
        return (mappings.data["metric_Energy"] * mappings.data["metric_Latency"]).min(), mappings
    spec = copy.deepcopy(spec)
    local_buffer: Memory = spec.architecture.nodes["LocalBuffer"]
    local_buffer.attributes.size = local_buffer_model.width * local_buffer_model.depth
    global_buffer: Memory = spec.architecture.nodes["GlobalBuffer"]
    global_buffer.attributes.size = global_buffer_model.width * global_buffer_model.depth
    for target, model in [(local_buffer, local_buffer_model), (global_buffer, global_buffer_model)]:
        target.actions["read"].arguments.energy = model.read() / model.width
        target.actions["write"].arguments.energy = model.write() / model.width
    main_memory: Memory = spec.architecture.nodes["MainMemory"]
    if parameterization == "Unfused":
        main_memory.constraints.storage.keep = "All()"
    elif parameterization == "FlashAttention":
        main_memory.constraints.storage.keep = "All() - QK - Q - K - V - I"
        main_memory.constraints.storage.bypass = "QK | Q | K | V | I"
    elif parameterization == "Fuse I":
        main_memory.constraints.storage.keep = "All() - I"
        main_memory.constraints.storage.bypass = "I"
    elif parameterization == "FFM":
        main_memory.constraints.storage.keep = "~Intermediates()"# - I - Q - K - V"# | AV | Z "
        main_memory.constraints.storage.bypass = "Q | K | V | I"#Q | K | V | I"# | QK | FFA"
        pass
    else:
        assert False, f"Parameterization {parameterization} not supported"
    register: Memory = spec.architecture.nodes["Register"]
    register.spatial.fanout["X"] = n_pes
    register.spatial.fanout["Y"] = n_pes
    
    spec.estimate_energy_area()
    flattened_architecture = spec.get_flattened_architecture()
    t0 = time.time()
    sims, decompress_data = get_sims(spec, flattened_architecture, tagger=tagger, metrics=Metrics.LATENCY | Metrics.ENERGY | Metrics.PER_COMPONENT_ENERGY) # metrics=Metrics.ENERGY | # | Metrics.PER_COMPONENT_ENERGY)
    pmapping_time = time.time() - t0
    total_pmappings = sum(p.mappings.n_pmappings for v in sims.values() for p in v)
    n_pareto_optimal_mappings = sum(len(p.mappings.data) for v in sims.values() for p in v)
    print(f'Took {pmapping_time:.2f} seconds to generate {total_pmappings} partial mappings ({total_pmappings / pmapping_time:.2f} per second). {n_pareto_optimal_mappings} pareto optimal mappings ({n_pareto_optimal_mappings / total_pmappings*100:.2f}% of total).')
    t0 = time.time()
    mappings = join_sims(sims, spec, flattened_architecture)
    join_time = time.time() - t0
    mappings.decompress(decompress_data)
    print(f"Pmappings: {pmapping_time:.2f}. Joining: {join_time:.2f}. Total Pmappings: {total_pmappings}. Total mappings: {mappings.n_pmappings}. Time per pmapping: {pmapping_time / total_pmappings:.2e}")
    pickle.dump(mappings, open(f"cache/{fname}.pkl", "wb"))
    if return_mappings:
        return mappings
    return (mappings.data["metric_Energy"] * mappings.data["metric_Latency"]).min(), mappings

print(f'Overall area budget: {area_budget * 1e6} mm^2')

parameterization2edp = {}
parameterization2mappings = {}

parameterizations = ["FFM", "Unfused"]#, "FlashAttention"]#, "FlashAttention", "Unfused"]

for glb_MB in [8]:#, 64, 32, 16]:#,16]:#16, 32, 64, 128]: # [16, 32, 64, 128]: # 16, 64
    cur_area_budget = area_budget
    glb_size = glb_MB * 1024 * 1024 * 8
    glb = CactiSRAM(technology="7nm", width=1024, depth=glb_size // 1024)
    cur_area_budget -= glb.get_area()
    # for sram_MB in [0.25, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]:
    for sram_MB in [4]:#, 1, 0.25]:#,0.5]:#[0.5,1,2,4]: # [0.25, 1, 4]: # 0.125, 0.5, 2
        sram_size = sram_MB * 1024 * 1024 * 8
        llb = CactiSRAM(technology="7nm", width=128, depth=sram_size // 128)
        remaining_area = cur_area_budget / 4 - llb.get_area() # Per-MXU
        if remaining_area < 0:
            break
        mac_dims = int((remaining_area / mac_area) ** 0.5)
        print(f"Global buffer: {glb_MB} MB, Local buffer: {sram_MB} MB, MAC dims: {mac_dims}x{mac_dims}")
        print(f'GLB read energy: {glb.read()}. LLB read energy: {llb.read()}')
        
        for parameterization in parameterizations: # "fuse"
            x, mappings = get_fused_mappings(
                spec,
                mac_dims,
                llb,
                glb,
                parameterization=parameterization,
            )
            if x != 0:
                parameterization2edp[f"{parameterization} {glb_MB}MB {sram_MB}MB {mac_dims}x{mac_dims}"] = x
                parameterization2mappings[f"{parameterization} {glb_MB}MB {sram_MB}MB {mac_dims}x{mac_dims}"] = mappings
# Out:
# INFO        Loading yaml file architecture/four_level.arch.yaml
# INFO        Found top key variables in architecture/four_level.arch.yaml
# INFO        Found top key architecture in architecture/four_level.arch.yaml
# INFO        Found top key component_classes in architecture/four_level.arch.yaml
# INFO        Loading yaml file workloads/mha_full.workload.yaml
# INFO        Found top key workload in workloads/mha_full.workload.yaml
# INFO        Loading yaml file workloads/mha_full.renames.yaml
# INFO        Found top key renames in workloads/mha_full.renames.yaml
# WARNING     Loading configuration file from /root/.config/fastfusion/config.yaml
# COMPUTE ENERGY / 8 ????????????
# COMPUTE ENERGY / 8 ????????????
# COMPUTE ENERGY / 8 ????????????
# COMPUTE ENERGY / 8 ????????????
# COMPUTE ENERGY / 8 ????????????
# Overall area budget: 39.657475727216784 mm^2
# INFO        Calculated "614e9 * 8 / 1.05e9" = 4678.0952380952385.
# INFO        Calculated "0.84e-12 / 8" = 1.05e-13.
# INFO        Calculated "0.5" = 0.5.
# Global buffer: 8 MB, Local buffer: 4 MB, MAC dims: 399x399
# GLB read energy: 4.0725446487730497e-10. LLB read energy: 4.2315915388286673e-11
# By default metrics optimizes for energy and latency.We should change to just energy or just latency at some point.
# Generating storage and loop choices for Einsum I: 6it [00:00, 87.54it/s]
# Generating Pmappings for I:   0%|          | 0/6 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
plt.style.use('default')
# plt.rcParams.update({'font.size': 28})

def plot_default_formatting(ax, grid_axis='both'):
    ax.tick_params(axis='both', which='major')#, labelsize=20)
    ax.tick_params(axis='both', which='minor')#, labelsize=20)
    legend = ax.legend()
    legend.get_frame().set_facecolor('white')
    legend.get_frame().set_edgecolor('black')
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
    if ax.get_legend() is None:
        legend = ax.legend(fontsize=24, ncol=2)
    ax.minorticks_on()
    ax.grid(axis=grid_axis, which='major', linestyle='-', linewidth='0.3', color='gray')
    ax.grid(axis=grid_axis, which='minor', linestyle='--', linewidth='0.1', color='lightgray')
    

def make_bar_chart(
    data,
    title,
    xlabel,
    ylabel,
    y_scale,
    output_file=None,
    normalize: bool = False,
    ylim=(None, None),
    xlim=(None, None),
):
    """
    Create a bar chart from the given data and save it as a PDF.
    """
    plt.figure(figsize=(16, 8))
    
    if isinstance(data, dict) and isinstance(next(iter(data.values())), dict):
        bar_width = 0.8 / len(data)
        keys = list(next(iter(data.values())).keys())
        x = range(len(keys))
        first = next(iter(data.values()))
            
        for i, (label, values) in enumerate(data.items()):
            bar_positions = [pos + i * bar_width for pos in x]
            to_plot = values
            if normalize:
                to_plot = {k: v / first[k] for k, v in values.items()}
            bars = plt.bar(bar_positions, to_plot.values(), width=bar_width, label=label)
        plt.xticks([pos + (len(data) - 1) * bar_width / 2 for pos in x], keys)
        plt.legend(loc='upper right', fontsize=10)
    else:
        keys = list(data.keys())
        bars = plt.bar(keys, data.values())

    # Set logarithmic scale for Y-axis if specified
    if y_scale == 'log':
        plt.yscale('log')

    # Add labels and title
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.ylim(ylim)
    plt.xlim(xlim)

    # Rotate X-axis labels vertically
    plt.xticks(rotation=90)
    
    plot_default_formatting(plt.gca(), grid_axis='y')
    
    if output_file is not None:
        with open(output_file, 'wb') as f:
            plt.savefig(f, format='pdf', bbox_inches='tight')

    # Show the plot
    plt.show()
print()
make_bar_chart(
    parameterization2edp,
    title=None,
    xlabel=None,
    ylabel="EDP",
    y_scale='linear'
)
# Out:
# /tmp/ipykernel_77828/1760616645.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   legend = ax.legend()

# %%
# # glb_MB = 128
# # sram_MB = 4
# # parameterization = ""

# # cur_area_budget = area_budget
# # glb_size = glb_MB * 1024 * 1024 * 8
# # glb = CactiSRAM(technology="7nm", width=1024, depth=glb_size // 1024)
# # cur_area_budget -= glb.get_area()
# # # for sram_MB in [0.25, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]:
# # sram_size = sram_MB * 1024 * 1024 * 8
# # llb = CactiSRAM(technology="7nm", width=128, depth=sram_size // 128)
# # remaining_area = cur_area_budget / 4 - llb.get_area() # Per-MXU
# # mac_dims = int((remaining_area / mac_area) ** 0.5)
# # print(f"Global buffer: {glb_MB} MB, Local buffer: {sram_MB} MB, MAC dims: {mac_dims}x{mac_dims}")
# # print(f'GLB read energy: {glb.read()}. LLB read energy: {llb.read()}')

from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_per_tensor_size, get_num_computes
for tensor, size in sorted(get_per_tensor_size(spec).items(), key=lambda x: x[1], reverse=True):
    print(f"{tensor}: {size}")
print(f"Number of computes: {get_num_computes(spec)}")
# Out:
# AV
# WV
# WFFA
# K
# V
# WK
# WFFB
# Z
# FFB
# I_in
# I
# WQ
# QK
# FFA
# Q
# WZ
# QK: 134217728
# WFFA: 67108864
# WFFB: 67108864
# FFA: 33554432
# WV: 16777216
# WK: 16777216
# WQ: 16777216
# WZ: 16777216
# AV: 8388608
# K: 8388608
# V: 8388608
# Z: 8388608
# FFB: 8388608
# I_in: 8388608
# I: 8388608
# Q: 8388608
# Number of computes: 446684987392

# %%
from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_rank_variable_bounds_for_all_einsums

parameterization2latencycols: list[dict[str, float]] = []
for p, mappings in parameterization2mappings.items():
    mappings._data = mappings.data.sort_values(by="metric_Energy", ascending=True)
    rank_variable_bounds = get_rank_variable_bounds_for_all_einsums(spec)

    row = {
        "Parameterization": p,
    }
    for col in mappings.data.columns:
        print(f'{col}: {mappings.data.iloc[0][col]}')
        # if "Latency" in col:
        # if "metric_Latency" in col:
        if "Energy" in col:
        # if "metric_Energy" in col:
            row[col] = mappings.data.iloc[0][col]
    parameterization2latencycols.append(row)

    # from fastfusion.mapper.FFM.visualization import make_mapping
    # from IPython.display import SVG
    # newmapping = make_mapping(mappings.data.iloc[0], spec.workload.einsum_names, get_rank_variable_bounds_for_all_einsums(spec))
    # for col in mappings.data.columns:
    #     print(f'{col}: {mappings.data.iloc[0][col]}')

    # display(SVG(newmapping.render()))
    
from pandas import DataFrame
df = DataFrame(parameterization2latencycols)
import pandas as pd
pd.set_option('display.max_columns', None)
df
    
# {'n1'}-1 || [GlobalBuffer] T1 sz 0 above 1
# TODO: Re-add -1 to the mapper one eisnum freenig
# compatibility2sims['Matmul1']["{'n1'}-1 || [GlobalBuffer] T1 sz 0 above 1"]
# Above 1: 8192
# Above 2: 8321
# compatibility2sims['Matmul2']["{'n1'}-1 || [GlobalBuffer] T1 sz 0 above 1, [GlobalBuffer] T2 sz 0 above 0"]
# Out:
# FFB__tile_shape0: 1.0
# FFB__tile_shape1: 2048.0
# FFB__tile_shape2: 16384.0
# FFB__tile_shape3: 1.0
# FFB__tile_shape4: 2048.0
# FFB__tile_shape5: 1.0
# FFB__tile_shape6: 1.0
# FFB__tile_shape7: 2048.0
# FFB__tile_shape8: 8.0
# FFB__tile_shape9: 1.0
# FFB__tile_shape10: 1.0
# FFB__tile_shape11: 16.0
# FFB__tile_shape12: 1.0
# FFB__tile_shape13: 1.0
# FFB__tile_shape14: 1.0
# FFB__tile_shape15: 1.0
# FFB__tile_shape16: 1.0
# FFB__tile_shape17: 1.0
# FFBRESOURCE_Register_LEVEL_2: nan
# FFBRESOURCE_LocalBuffer_LEVEL_2: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_1: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_2: nan
# FFBRESOURCE_MainMemory_LEVEL_0: 603979776
# FFBmetric_Latency: 8388608.0
# FFBcompute_Latency: 8388608.0
# FFBLocalBuffer_Latency: 0
# FFBRegister_Latency: 0
# FFBMainMemory_Latency: 129108.05472285078
# FFBGlobalBuffer_Latency: 0
# FFBmetric_Energy: 0.40669325012747787
# FFB('LocalBuffer', 'read')_Energy: 0.0908727363464972
# FFB('LocalBuffer', 'write')_Energy: 0.07930064187814245
# FFB('Register', 'read')_Energy: 0
# FFB('Register', 'write')_Energy: 0
# FFB('MainMemory', 'read')_Energy: 0.00047177531392
# FFB('MainMemory', 'write')_Energy: 5.897191424e-05
# FFB('GlobalBuffer', 'read')_Energy: 0.22153051028736342
# FFB('GlobalBuffer', 'write')_Energy: 2.7524272755581185e-05
# FFB('MAC', 'compute')_Energy: 0.01443109011456
# FFBRESOURCE_Register_LEVEL_1: nan
# FFBRESOURCE_LocalBuffer_LEVEL_1: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_0: 335544320.0
# FFBRESOURCE_Register_LEVEL_0: 8.0
# FFBRESOURCE_LocalBuffer_LEVEL_0: 147456.0
# FFB__MAPPING: type=None nodes=[Storage(type=None, tensors=['WFFB'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WFFB', memory='MainMemory'), Reservation(type=None, tensor='WFFB', memory='MainMemory'), Storage(type=None, tensors=['FFB'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='FFB', memory='MainMemory'), Reservation(type=None, tensor='FFB', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['FFB'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5' ...
# FFA__tile_shape0: 1.0
# FFA__tile_shape1: 16384.0
# FFA__tile_shape2: 2048.0
# FFA__tile_shape3: 1.0
# FFA__tile_shape4: 2048.0
# FFA__tile_shape5: 1.0
# FFA__tile_shape6: 1.0
# FFA__tile_shape7: 2048.0
# FFA__tile_shape8: 8.0
# FFA__tile_shape9: 1.0
# FFA__tile_shape10: 1.0
# FFA__tile_shape11: 16.0
# FFA__tile_shape12: 1.0
# FFA__tile_shape13: 1.0
# FFA__tile_shape14: 1.0
# FFA__tile_shape15: 1.0
# FFA__tile_shape16: 1.0
# FFA__tile_shape17: 1.0
# FFARESOURCE_Register_LEVEL_2: nan
# FFARESOURCE_LocalBuffer_LEVEL_2: nan
# FFARESOURCE_GlobalBuffer_LEVEL_2: nan
# FFARESOURCE_MainMemory_LEVEL_0: 603979776
# FFAmetric_Latency: 8388608.0
# FFAcompute_Latency: 8388608.0
# FFALocalBuffer_Latency: 0
# FFARegister_Latency: 0
# FFAMainMemory_Latency: 129108.05472285076
# FFAGlobalBuffer_Latency: 0
# FFAmetric_Energy: 0.40672827618156177
# FFA('LocalBuffer', 'read')_Energy: 0.0908727363464972
# FFA('LocalBuffer', 'write')_Energy: 0.07930790184718739
# FFA('Register', 'read')_Energy: 0
# FFA('Register', 'write')_Energy: 0
# FFA('MainMemory', 'read')_Energy: 0.0005307472281599999
# FFA('MainMemory', 'write')_Energy: 0.0
# FFA('GlobalBuffer', 'read')_Energy: 0.221516989963269
# FFA('GlobalBuffer', 'write')_Energy: 6.881068188895299e-05
# FFA('MAC', 'compute')_Energy: 0.01443109011456
# FFARESOURCE_Register_LEVEL_1: nan
# FFARESOURCE_LocalBuffer_LEVEL_1: nan
# FFARESOURCE_GlobalBuffer_LEVEL_1: nan
# FFARESOURCE_Register_LEVEL_0: 8.0
# FFARESOURCE_LocalBuffer_LEVEL_0: 147456.0
# FFARESOURCE_GlobalBuffer_LEVEL_0: 335544320.0
# FFA__MAPPING: type=None nodes=[Storage(type=None, tensors=['Z'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='Z', memory='MainMemory'), Reservation(type=None, tensor='Z', memory='MainMemory'), Storage(type=None, tensors=['WFFA'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WFFA', memory='MainMemory'), Reservation(type=None, tensor='WFFA', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='c', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['Z'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=Non ...
# Z__tile_shape0: 1.0
# Z__tile_shape1: 128.0
# Z__tile_shape2: 32.0
# Z__tile_shape3: 2048.0
# Z__tile_shape4: 1.0
# Z__tile_shape5: 1.0
# Z__tile_shape6: 1024.0
# Z__tile_shape7: 16.0
# Z__tile_shape8: 1.0
# Z__tile_shape9: 1.0
# Z__tile_shape10: 1.0
# Z__tile_shape11: 8.0
# Z__tile_shape12: 1.0
# Z__tile_shape13: 1.0
# Z__tile_shape14: 1.0
# Z__tile_shape15: 1.0
# Z__tile_shape16: 1.0
# Z__tile_shape17: 1.0
# Z__tile_shape18: 1.0
# ZRESOURCE_Register_LEVEL_0: 8
# ZRESOURCE_LocalBuffer_LEVEL_0: 139264.0
# ZRESOURCE_GlobalBuffer_LEVEL_0: 67125248.0
# ZRESOURCE_MainMemory_LEVEL_0: 268435456
# Zmetric_Latency: 1048576.0
# Zcompute_Latency: 1048576.0
# ZRegister_Latency: 0
# ZLocalBuffer_Latency: 0
# ZMainMemory_Latency: 57381.357654600535
# ZGlobalBuffer_Latency: 0
# Zmetric_Energy: 0.10194081778654618
# Z('Register', 'read')_Energy: 0
# Z('Register', 'write')_Energy: 0
# Z('LocalBuffer', 'read')_Energy: 0.0227181840866243
# Z('LocalBuffer', 'write')_Energy: 0.019826975461796875
# Z('MainMemory', 'read')_Energy: 0.00029485957119999997
# Z('MainMemory', 'write')_Energy: 5.897191424e-05
# Z('GlobalBuffer', 'read')_Energy: 0.055392767814911634
# Z('GlobalBuffer', 'write')_Energy: 4.12864091333719e-05
# Z('MAC', 'compute')_Energy: 0.00360777252864
# Z__MAPPING: type=None nodes=[Storage(type=None, tensors=['Z'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='Z', memory='MainMemory'), Reservation(type=None, tensor='Z', memory='MainMemory'), Storage(type=None, tensors=['WZ'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WZ', memory='MainMemory'), Reservation(type=None, tensor='WZ', memory='MainMemory'), Storage(type=None, tensors=['AV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_ ...
# AV__tile_shape0: 1.0
# AV__tile_shape1: 8.0
# AV__tile_shape2: 1.0
# AV__tile_shape3: 128.0
# AV__tile_shape4: 2048.0
# AV__tile_shape5: 1.0
# AV__tile_shape6: 1.0
# AV__tile_shape7: 1.0
# AV__tile_shape8: 2048.0
# AV__tile_shape9: 2048.0
# AV__tile_shape10: 8.0
# AV__tile_shape11: 1.0
# AV__tile_shape12: 1.0
# AV__tile_shape13: 1.0
# AV__tile_shape14: 16.0
# AV__tile_shape15: 1.0
# AV__tile_shape16: 1.0
# AV__tile_shape17: 1.0
# AV__tile_shape18: 1.0
# AV__tile_shape19: 1.0
# AV__tile_shape20: 1.0
# AVRESOURCE_Register_LEVEL_2: 8
# AVRESOURCE_LocalBuffer_LEVEL_2: 147456.0
# AVRESOURCE_GlobalBuffer_LEVEL_1: 268435456.0
# AVRESOURCE_GlobalBuffer_LEVEL_2: 285229056.0
# AVRESOURCE_MainMemory_LEVEL_0: 67108864
# AVmetric_Latency: 1048576.0
# AVcompute_Latency: 1048576.0
# AVLocalBuffer_Latency: 0
# AVRegister_Latency: 0
# AVGlobalBuffer_Latency: 0
# AVMainMemory_Latency: 14345.339413650147
# AVmetric_Energy: 0.05088083661396451
# AV('LocalBuffer', 'read')_Energy: 0.0113590920433122
# AV('LocalBuffer', 'write')_Energy: 0.009914697725739254
# AV('Register', 'read')_Energy: 0
# AV('Register', 'write')_Energy: 0
# AV('GlobalBuffer', 'read')_Energy: 0.027716664393597476
# AV('GlobalBuffer', 'write')_Energy: 2.7524272755581202e-05
# AV('MainMemory', 'read')_Energy: 0.0
# AV('MainMemory', 'write')_Energy: 5.897191424e-05
# AV('MAC', 'compute')_Energy: 0.00180388626432
# AV__MAPPING: type=None nodes=[Storage(type=None, tensors=['AV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='AV', memory='MainMemory'), Reservation(type=None, tensor='AV', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['QK'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='QK', memory='GlobalBuffer'), Reservation(type=None, tensor='QK', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='f', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='p', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['V'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', at ...
# QK__tile_shape0: 1.0
# QK__tile_shape1: 8.0
# QK__tile_shape2: 1.0
# QK__tile_shape3: 128.0
# QK__tile_shape4: 1.0
# QK__tile_shape5: 2048.0
# QK__tile_shape6: 2048.0
# QK__tile_shape7: 1.0
# QK__tile_shape8: 1.0
# QK__tile_shape9: 2048.0
# QK__tile_shape10: 1.0
# QK__tile_shape11: 8.0
# QK__tile_shape12: 1.0
# QK__tile_shape13: 1.0
# QK__tile_shape14: 16.0
# QK__tile_shape15: 1.0
# QK__tile_shape16: 1.0
# QK__tile_shape17: 1.0
# QK__tile_shape18: 1.0
# QK__tile_shape19: 1.0
# QK__tile_shape20: 1.0
# QK__tile_shape21: 1.0
# QKRESOURCE_Register_LEVEL_3: nan
# QKRESOURCE_LocalBuffer_LEVEL_3: nan
# QKRESOURCE_GlobalBuffer_LEVEL_1: 268435456.0
# QKRESOURCE_GlobalBuffer_LEVEL_3: nan
# QKmetric_Latency: 1048576.0
# QKcompute_Latency: 1048576.0
# QKLocalBuffer_Latency: 0
# QKRegister_Latency: 0
# QKGlobalBuffer_Latency: 0
# QKmetric_Energy: 0.05103731413014387
# QK('LocalBuffer', 'read')_Energy: 0.0113590920433122
# QK('LocalBuffer', 'write')_Energy: 0.009950997570964074
# QK('Register', 'read')_Energy: 0
# QK('Register', 'write')_Energy: 0
# QK('GlobalBuffer', 'read')_Energy: 0.027703144069503038
# QK('GlobalBuffer', 'write')_Energy: 0.0002201941820446492
# QK('MAC', 'compute')_Energy: 0.00180388626432
# QKRESOURCE_Register_LEVEL_4: nan
# QKRESOURCE_LocalBuffer_LEVEL_4: nan
# QKRESOURCE_GlobalBuffer_LEVEL_4: nan
# QKRESOURCE_GlobalBuffer_LEVEL_2: 301989888.0
# QKRESOURCE_Register_LEVEL_2: 8.0
# QKRESOURCE_LocalBuffer_LEVEL_2: 147456.0
# QK__MAPPING: type=None nodes=[Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['QK'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='QK', memory='GlobalBuffer'), Reservation(type=None, tensor='QK', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['K'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='K', memory='GlobalBuffer'), Reservation(type=None, tensor='K', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', ...
# Q__tile_shape0: 1.0
# Q__tile_shape1: 2048.0
# Q__tile_shape2: 1.0
# Q__tile_shape3: 128.0
# Q__tile_shape4: 8.0
# Q__tile_shape5: 1.0
# Q__tile_shape6: 2048.0
# Q__tile_shape7: 1.0
# Q__tile_shape8: 1.0
# Q__tile_shape9: 1.0
# Q__tile_shape10: 2048.0
# Q__tile_shape11: 8.0
# Q__tile_shape12: 1.0
# Q__tile_shape13: 1.0
# Q__tile_shape14: 1.0
# Q__tile_shape15: 16.0
# Q__tile_shape16: 1.0
# Q__tile_shape17: 1.0
# Q__tile_shape18: 1.0
# Q__tile_shape19: 1.0
# Q__tile_shape20: 1.0
# Q__tile_shape21: 1.0
# Q__tile_shape22: 1.0
# QRESOURCE_Register_LEVEL_4: nan
# QRESOURCE_LocalBuffer_LEVEL_4: nan
# QRESOURCE_GlobalBuffer_LEVEL_1: nan
# QRESOURCE_GlobalBuffer_LEVEL_4: nan
# QRESOURCE_MainMemory_LEVEL_0: 134217728
# Qmetric_Latency: 2097152.0
# Qcompute_Latency: 2097152.0
# QRegister_Latency: 0
# QLocalBuffer_Latency: 0
# QMainMemory_Latency: 28690.678827300246
# QGlobalBuffer_Latency: 0
# Qmetric_Energy: 0.10166388553273621
# Q('Register', 'read')_Energy: 0
# Q('Register', 'write')_Energy: 0
# Q('LocalBuffer', 'read')_Energy: 0.0227181840866243
# Q('LocalBuffer', 'write')_Energy: 0.019826975461796868
# Q('MainMemory', 'read')_Energy: 0.00011794382848
# Q('MainMemory', 'write')_Energy: 0.0
# Q('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# Q('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# Q('MAC', 'compute')_Energy: 0.00360777252864
# QRESOURCE_Register_LEVEL_3: nan
# QRESOURCE_LocalBuffer_LEVEL_3: nan
# QRESOURCE_GlobalBuffer_LEVEL_3: nan
# QRESOURCE_Register_LEVEL_2: 8.0
# QRESOURCE_LocalBuffer_LEVEL_2: 147456.0
# QRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# QRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# QRESOURCE_Register_LEVEL_1: nan
# QRESOURCE_LocalBuffer_LEVEL_1: nan
# Q__MAPPING: type=None nodes=[Storage(type=None, tensors=['WQ'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WQ', memory='MainMemory'), Reservation(type=None, tensor='WQ', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['Q'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# K__tile_shape0: 1.0
# K__tile_shape1: 2048.0
# K__tile_shape2: 1.0
# K__tile_shape3: 128.0
# K__tile_shape4: 8.0
# K__tile_shape5: 1.0
# K__tile_shape6: 2048.0
# K__tile_shape7: 1.0
# K__tile_shape8: 1.0
# K__tile_shape9: 1.0
# K__tile_shape10: 2048.0
# K__tile_shape11: 8.0
# K__tile_shape12: 1.0
# K__tile_shape13: 1.0
# K__tile_shape14: 1.0
# K__tile_shape15: 16.0
# K__tile_shape16: 1.0
# K__tile_shape17: 1.0
# K__tile_shape18: 1.0
# K__tile_shape19: 1.0
# K__tile_shape20: 1.0
# K__tile_shape21: 1.0
# K__tile_shape22: 1.0
# KRESOURCE_Register_LEVEL_4: nan
# KRESOURCE_LocalBuffer_LEVEL_4: nan
# KRESOURCE_GlobalBuffer_LEVEL_1: nan
# KRESOURCE_GlobalBuffer_LEVEL_4: nan
# KRESOURCE_MainMemory_LEVEL_0: 134217728
# Kmetric_Latency: 2097152.0
# Kcompute_Latency: 2097152.0
# KLocalBuffer_Latency: 0
# KRegister_Latency: 0
# KMainMemory_Latency: 28690.678827300246
# KGlobalBuffer_Latency: 0
# Kmetric_Energy: 0.10166388553273621
# K('LocalBuffer', 'read')_Energy: 0.0227181840866243
# K('LocalBuffer', 'write')_Energy: 0.019826975461796868
# K('Register', 'read')_Energy: 0
# K('Register', 'write')_Energy: 0
# K('MainMemory', 'read')_Energy: 0.00011794382848
# K('MainMemory', 'write')_Energy: 0.0
# K('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# K('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# K('MAC', 'compute')_Energy: 0.00360777252864
# KRESOURCE_Register_LEVEL_3: nan
# KRESOURCE_LocalBuffer_LEVEL_3: nan
# KRESOURCE_GlobalBuffer_LEVEL_3: nan
# KRESOURCE_Register_LEVEL_2: 8.0
# KRESOURCE_LocalBuffer_LEVEL_2: 147456.0
# KRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# KRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# KRESOURCE_Register_LEVEL_1: nan
# KRESOURCE_LocalBuffer_LEVEL_1: nan
# K__MAPPING: type=None nodes=[Storage(type=None, tensors=['WK'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WK', memory='MainMemory'), Reservation(type=None, tensor='WK', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['K'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# V__tile_shape0: 1.0
# V__tile_shape1: 2048.0
# V__tile_shape2: 1.0
# V__tile_shape3: 128.0
# V__tile_shape4: 8.0
# V__tile_shape5: 1.0
# V__tile_shape6: 2048.0
# V__tile_shape7: 1.0
# V__tile_shape8: 1.0
# V__tile_shape9: 1.0
# V__tile_shape10: 2048.0
# V__tile_shape11: 8.0
# V__tile_shape12: 1.0
# V__tile_shape13: 1.0
# V__tile_shape14: 1.0
# V__tile_shape15: 16.0
# V__tile_shape16: 1.0
# V__tile_shape17: 1.0
# V__tile_shape18: 1.0
# V__tile_shape19: 1.0
# V__tile_shape20: 1.0
# V__tile_shape21: 1.0
# V__tile_shape22: 1.0
# VRESOURCE_Register_LEVEL_4: nan
# VRESOURCE_LocalBuffer_LEVEL_4: nan
# VRESOURCE_GlobalBuffer_LEVEL_1: nan
# VRESOURCE_GlobalBuffer_LEVEL_4: nan
# VRESOURCE_MainMemory_LEVEL_0: 134217728
# Vmetric_Latency: 2097152.0
# Vcompute_Latency: 2097152.0
# VLocalBuffer_Latency: 0
# VRegister_Latency: 0
# VMainMemory_Latency: 28690.678827300246
# VGlobalBuffer_Latency: 0
# Vmetric_Energy: 0.10166388553273621
# V('LocalBuffer', 'read')_Energy: 0.0227181840866243
# V('LocalBuffer', 'write')_Energy: 0.019826975461796868
# V('Register', 'read')_Energy: 0
# V('Register', 'write')_Energy: 0
# V('MainMemory', 'read')_Energy: 0.00011794382848
# V('MainMemory', 'write')_Energy: 0.0
# V('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# V('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# V('MAC', 'compute')_Energy: 0.00360777252864
# VRESOURCE_Register_LEVEL_3: nan
# VRESOURCE_LocalBuffer_LEVEL_3: nan
# VRESOURCE_GlobalBuffer_LEVEL_3: nan
# VRESOURCE_Register_LEVEL_2: 8.0
# VRESOURCE_LocalBuffer_LEVEL_2: 147456.0
# VRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# VRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# VRESOURCE_Register_LEVEL_1: nan
# VRESOURCE_LocalBuffer_LEVEL_1: nan
# V__MAPPING: type=None nodes=[Storage(type=None, tensors=['WV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WV', memory='MainMemory'), Reservation(type=None, tensor='WV', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['V'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# I__tile_shape0: 1.0
# I__tile_shape1: 4096.0
# I__tile_shape2: 2048.0
# I__tile_shape3: 1.0
# I__tile_shape4: 2048.0
# I__tile_shape5: 32.0
# I__tile_shape6: 1.0
# I__tile_shape7: 2048.0
# I__tile_shape8: 8.0
# I__tile_shape9: 1.0
# I__tile_shape10: 32.0
# I__tile_shape11: 4.0
# I__tile_shape12: 1.0
# I__tile_shape13: 1.0
# I__tile_shape14: 1.0
# IRESOURCE_LocalBuffer_LEVEL_2: nan
# IRESOURCE_GlobalBuffer_LEVEL_2: nan
# IRESOURCE_MainMemory_LEVEL_0: 67108864
# Imetric_Latency: 128.0
# Icompute_Latency: 128.0
# IGlobalBuffer_Latency: 0
# ILocalBuffer_Latency: 0
# IMainMemory_Latency: 14345.3394136501
# Imetric_Energy: 0.000108510510124215
# I('GlobalBuffer', 'read')_Energy: 1.35203240944378e-05
# I('GlobalBuffer', 'write')_Energy: 2.75242727555812e-05
# I('LocalBuffer', 'read')_Energy: 2.77321583088676e-06
# I('LocalBuffer', 'write')_Energy: 4.83997936330938e-06
# I('MainMemory', 'read')_Energy: 5.897191424e-05
# I('MainMemory', 'write')_Energy: 0.0
# I('MAC', 'compute')_Energy: 8.8080384e-07
# IRESOURCE_LocalBuffer_LEVEL_1: nan
# IRESOURCE_GlobalBuffer_LEVEL_1: nan
# IRESOURCE_LocalBuffer_LEVEL_0: 131072.0
# IRESOURCE_GlobalBuffer_LEVEL_0: 67633152.0
# ...
# I__tile_shape0: 1.0
# I__tile_shape1: 2048.0
# I__tile_shape2: 32.0
# I__tile_shape3: 1.0
# I__tile_shape4: 2048.0
# I__tile_shape5: 8.0
# I__tile_shape6: 1.0
# I__tile_shape7: 32.0
# I__tile_shape8: 4.0
# I__tile_shape9: 1.0
# I__tile_shape10: 1.0
# I__tile_shape11: 1.0
# IRESOURCE_LocalBuffer_LEVEL_0: 131072.0
# IRESOURCE_GlobalBuffer_LEVEL_0: 1048576.0
# IRESOURCE_MainMemory_LEVEL_0: 134217728
# Imetric_Latency: 128.0
# Icompute_Latency: 128.0
# IGlobalBuffer_Latency: 0
# ILocalBuffer_Latency: 0
# IMainMemory_Latency: 28690.6788273002
# Imetric_Energy: 0.000194764884836444
# I('GlobalBuffer', 'read')_Energy: 2.70406481888756e-05
# I('GlobalBuffer', 'write')_Energy: 4.12864091333718e-05
# I('LocalBuffer', 'read')_Energy: 2.77321583088676e-06
# I('LocalBuffer', 'write')_Energy: 4.83997936330938e-06
# I('MainMemory', 'read')_Energy: 5.897191424e-05
# I('MainMemory', 'write')_Energy: 5.897191424e-05
# I('MAC', 'compute')_Energy: 8.8080384e-07
# I__MAPPING: type=None nodes=[Storage(type=None, tensors=['I_in'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='~All', keep='All()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I_in', memory='MainMemory'), Reservation(type=None, tensor='I_in', memory='MainMemory'), Storage(type=None, tensors=['I'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='~All', keep='All()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='MainMemory'), Reservation(type=None, tensor='I', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='d', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I_in'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGr ...
# metric_Latency: 13631616.0
# metric_Energy: 1.327702613277999
#             Parameterization  FFBmetric_Energy  \
# 0      FFM 128MB 4MB 128x128          0.406693
# 1  Unfused 128MB 4MB 128x128          0.407456
#
#    FFB('LocalBuffer', 'read')_Energy  FFB('LocalBuffer', 'write')_Energy  \
# 0                           0.090873                            0.079301
# 1                           0.090873                            0.079301
#
#    FFB('Register', 'read')_Energy  FFB('Register', 'write')_Energy  \
# 0                               0                                0
# 1                               0                                0
#
#    FFB('MainMemory', 'read')_Energy  FFB('MainMemory', 'write')_Energy  \
# 0                          0.000472                           0.000059
# 1                          0.001179                           0.000059
#
#    FFB('GlobalBuffer', 'read')_Energy  FFB('GlobalBuffer', 'write')_Energy  \
# 0                            0.221531                             0.000028
# 1                            0.221531                             0.000083
#
#    FFB('MAC', 'compute')_Energy  FFAmetric_Energy  \
# 0                      0.014431          0.406728
# 1                      0.014431          0.407545
#
#    FFA('LocalBuffer', 'read')_Energy  FFA('LocalBuffer', 'write')_Energy  \
# 0                           0.090873                            0.079308
# 1                           0.090873                            0.079308
#
#    FFA('Register', 'read')_Energy  FFA('Register', 'write')_Energy  \
# 0                               0                                0
# 1                               0                                0
#
#    FFA('MainMemory', 'read')_Energy  FFA('MainMemory', 'write')_Energy  \
# 0                          0.000531                           0.000000
# 1                          0.001003                           0.000236
#
#    FFA('GlobalBuffer', 'read')_Energy  FFA('GlobalBuffer', 'write')_Energy  \
# 0                            0.221517                             0.000069
# 1                            0.221571                             0.000124
#
#    FFA('MAC', 'compute')_Energy  Zmetric_Energy  Z('Register', 'read')_Energy  \
# 0                      0.014431        0.101941                             0
# 1                      0.014431        0.101941                             0
#
#    Z('Register', 'write')_Energy  Z('LocalBuffer', 'read')_Energy  \
# 0                              0                         0.022718
# 1                              0                         0.022718
#
#    Z('LocalBuffer', 'write')_Energy  Z('MainMemory', 'read')_Energy  \
# 0                          0.019827                        0.000295
# 1                          0.019827                        0.000295
#
#    Z('MainMemory', 'write')_Energy  Z('GlobalBuffer', 'read')_Energy  \
# 0                         0.000059                          0.055393
# 1                         0.000059                          0.055393
#
#    Z('GlobalBuffer', 'write')_Energy  Z('MAC', 'compute')_Energy  \
# 0                           0.000041                    0.003608
# 1                           0.000041                    0.003608
#
#    AVmetric_Energy  AV('LocalBuffer', 'read')_Energy  \
# 0         0.050881                          0.011359
# 1         0.052149                          0.011359
#
#    AV('LocalBuffer', 'write')_Energy  AV('Register', 'read')_Energy  \
# 0                           0.009915                              0
# 1                           0.009915                              0
#
#    AV('Register', 'write')_Energy  AV('GlobalBuffer', 'read')_Energy  \
# 0                               0                           0.027717
# 1                               0                           0.027703
#
#    AV('GlobalBuffer', 'write')_Energy  AV('MainMemory', 'read')_Energy  \
# 0                            0.000028                         0.000000
# 1                            0.000248                         0.001061
#
#    AV('MainMemory', 'write')_Energy  AV('MAC', 'compute')_Energy  \
# 0                          0.000059                     0.001804
# 1                          0.000059                     0.001804
#
#    QKmetric_Energy  QK('LocalBuffer', 'read')_Energy  \
# 0         0.051037                          0.011359
# 1         0.052595                          0.011359
#
#    QK('LocalBuffer', 'write')_Energy  QK('Register', 'read')_Energy  \
# 0                           0.009951                              0
# 1                           0.009951                              0
#
#    QK('Register', 'write')_Energy  QK('GlobalBuffer', 'read')_Energy  \
# 0                               0                           0.027703
# 1                               0                           0.027906
#
#    QK('GlobalBuffer', 'write')_Energy  QK('MAC', 'compute')_Energy  \
# 0                            0.000220                     0.001804
# 1                            0.000454                     0.001804
#
#    Qmetric_Energy  Q('Register', 'read')_Energy  \
# 0        0.101664                             0
# 1        0.101941                             0
#
#    Q('Register', 'write')_Energy  Q('LocalBuffer', 'read')_Energy  \
# 0                              0                         0.022718
# 1                              0                         0.022718
#
#    Q('LocalBuffer', 'write')_Energy  Q('MainMemory', 'read')_Energy  \
# 0                          0.019827                        0.000118
# 1                          0.019827                        0.000295
#
#    Q('MainMemory', 'write')_Energy  Q('GlobalBuffer', 'read')_Energy  \
# 0                         0.000000                          0.055379
# 1                         0.000059                          0.055393
#
#    Q('GlobalBuffer', 'write')_Energy  Q('MAC', 'compute')_Energy  \
# 0                           0.000014                    0.003608
# 1                           0.000041                    0.003608
#
#    Kmetric_Energy  K('LocalBuffer', 'read')_Energy  \
# 0        0.101664                         0.022718
# 1        0.101941                         0.022718
#
#    K('LocalBuffer', 'write')_Energy  K('Register', 'read')_Energy  \
# 0                          0.019827                             0
# 1                          0.019827                             0
#
#    K('Register', 'write')_Energy  K('MainMemory', 'read')_Energy  \
# 0                              0                        0.000118
# 1                              0                        0.000295
#
#    K('MainMemory', 'write')_Energy  K('GlobalBuffer', 'read')_Energy  \
# 0                         0.000000                          0.055379
# 1                         0.000059                          0.055393
#
#    K('GlobalBuffer', 'write')_Energy  K('MAC', 'compute')_Energy  \
# 0                           0.000014                    0.003608
# 1                           0.000041                    0.003608
#
#    Vmetric_Energy  V('LocalBuffer', 'read')_Energy  \
# 0        0.101664                         0.022718
# 1        0.101941                         0.022718
#
#    V('LocalBuffer', 'write')_Energy  V('Register', 'read')_Energy  \
# 0                          0.019827                             0
# 1                          0.019827                             0
#
#    V('Register', 'write')_Energy  V('MainMemory', 'read')_Energy  \
# 0                              0                        0.000118
# 1                              0                        0.000295
#
#    V('MainMemory', 'write')_Energy  V('GlobalBuffer', 'read')_Energy  \
# 0                         0.000000                          0.055379
# 1                         0.000059                          0.055393
#
#    V('GlobalBuffer', 'write')_Energy  V('MAC', 'compute')_Energy  \
# 0                           0.000014                    0.003608
# 1                           0.000041                    0.003608
#
#    Imetric_Energy  I('GlobalBuffer', 'read')_Energy  \
# 0        0.000109                          0.000014
# 1        0.000195                          0.000027
#
#    I('GlobalBuffer', 'write')_Energy  I('LocalBuffer', 'read')_Energy  \
# 0                           0.000028                         0.000003
# 1                           0.000041                         0.000003
#
#    I('LocalBuffer', 'write')_Energy  I('MainMemory', 'read')_Energy  \
# 0                          0.000005                        0.000059
# 1                          0.000005                        0.000059
#
#    I('MainMemory', 'write')_Energy  I('MAC', 'compute')_Energy  metric_Energy  \
# 0                         0.000000                8.808038e-07       1.322381
# 1                         0.000059                8.808038e-07       1.327703
#
#    QK('MainMemory', 'read')_Energy  QK('MainMemory', 'write')_Energy
# 0                              NaN                               NaN
# 1                         0.000177                          0.000944

# %%
from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_rank_variable_bounds_for_all_einsums

sram_size = 4 * 1024 * 1024 * 8
llb = CactiSRAM(technology="7nm", width=128, depth=sram_size // 128)
mac_dims = int((((area_budget - glb.get_area()) / 4 - llb.get_area()) / mac_area)** 0.5)
mappings = get_fused_mappings(
    spec,
    mac_dims,
    llb,
    glb,
    return_mappings=True,
    parameterization="FFM"
)
mappings._data = mappings.data.sort_values(by="metric_Latency", ascending=True).head()
rank_variable_bounds = get_rank_variable_bounds_for_all_einsums(spec)
from fastfusion.mapper.FFM.visualization import make_mapping
from IPython.display import SVG
newmapping = make_mapping(mappings.data.iloc[0], spec.workload.einsum_names, get_rank_variable_bounds_for_all_einsums(spec))
a = {}
for col in mappings.data.columns:
    print(f'{col}: {mappings.data.iloc[0][col]}')
    if "Latency" in col:
        a[col] = mappings.data.iloc[0][col]
display(SVG(newmapping.render()))
# Out:
# Loading from cache: FFM e7587cf921a2eb76dfecd9d2444e4ca7
# FFB__tile_shape0: 1.0
# FFB__tile_shape1: 2048.0
# FFB__tile_shape2: 16384.0
# FFB__tile_shape3: 1.0
# FFB__tile_shape4: 512.0
# FFB__tile_shape5: 1.0
# FFB__tile_shape6: 1.0
# FFB__tile_shape7: 512.0
# FFB__tile_shape8: 32.0
# FFB__tile_shape9: 1.0
# FFB__tile_shape10: 1.0
# FFB__tile_shape11: 4.0
# FFB__tile_shape12: 1.0
# FFB__tile_shape13: 1.0
# FFB__tile_shape14: 1.0
# FFB__tile_shape15: 1.0
# FFB__tile_shape16: 1.0
# FFB__tile_shape17: 1.0
# FFBRESOURCE_Register_LEVEL_2: nan
# FFBRESOURCE_LocalBuffer_LEVEL_2: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_1: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_2: nan
# FFBRESOURCE_MainMemory_LEVEL_0: 603979776
# FFBmetric_Latency: 2097152.0
# FFBcompute_Latency: 2097152.0
# FFBLocalBuffer_Latency: 0
# FFBRegister_Latency: 0
# FFBMainMemory_Latency: 129108.05472285078
# FFBGlobalBuffer_Latency: 0
# FFBmetric_Energy: 0.40810857606923784
# FFB('LocalBuffer', 'read')_Energy: 0.0908727363464972
# FFB('LocalBuffer', 'write')_Energy: 0.07930064187814245
# FFB('Register', 'read')_Energy: 0
# FFB('Register', 'write')_Energy: 0
# FFB('MainMemory', 'read')_Energy: 0.00188710125568
# FFB('MainMemory', 'write')_Energy: 5.897191424e-05
# FFB('GlobalBuffer', 'read')_Energy: 0.22153051028736342
# FFB('GlobalBuffer', 'write')_Energy: 2.7524272755581185e-05
# FFB('MAC', 'compute')_Energy: 0.01443109011456
# FFBRESOURCE_Register_LEVEL_1: nan
# FFBRESOURCE_LocalBuffer_LEVEL_1: nan
# FFBRESOURCE_GlobalBuffer_LEVEL_0: 335544320.0
# FFBRESOURCE_Register_LEVEL_0: 8.0
# FFBRESOURCE_LocalBuffer_LEVEL_0: 135168.0
# FFB__MAPPING: type=None nodes=[Storage(type=None, tensors=['WFFB'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WFFB', memory='MainMemory'), Reservation(type=None, tensor='WFFB', memory='MainMemory'), Storage(type=None, tensors=['FFB'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='FFB', memory='MainMemory'), Reservation(type=None, tensor='FFB', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['FFB'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5' ...
# FFA__tile_shape0: 1.0
# FFA__tile_shape1: 16384.0
# FFA__tile_shape2: 2048.0
# FFA__tile_shape3: 1.0
# FFA__tile_shape4: 512.0
# FFA__tile_shape5: 1.0
# FFA__tile_shape6: 1.0
# FFA__tile_shape7: 512.0
# FFA__tile_shape8: 32.0
# FFA__tile_shape9: 1.0
# FFA__tile_shape10: 1.0
# FFA__tile_shape11: 4.0
# FFA__tile_shape12: 1.0
# FFA__tile_shape13: 1.0
# FFA__tile_shape14: 1.0
# FFA__tile_shape15: 1.0
# FFA__tile_shape16: 1.0
# FFA__tile_shape17: 1.0
# FFARESOURCE_Register_LEVEL_2: nan
# FFARESOURCE_LocalBuffer_LEVEL_2: nan
# FFARESOURCE_GlobalBuffer_LEVEL_2: nan
# FFARESOURCE_MainMemory_LEVEL_0: 603979776
# FFAmetric_Latency: 2097152.0
# FFAcompute_Latency: 2097152.0
# FFALocalBuffer_Latency: 0
# FFARegister_Latency: 0
# FFAMainMemory_Latency: 129108.05472285076
# FFAGlobalBuffer_Latency: 0
# FFAmetric_Energy: 0.40814360212332174
# FFA('LocalBuffer', 'read')_Energy: 0.0908727363464972
# FFA('LocalBuffer', 'write')_Energy: 0.07930790184718739
# FFA('Register', 'read')_Energy: 0
# FFA('Register', 'write')_Energy: 0
# FFA('MainMemory', 'read')_Energy: 0.00194607316992
# FFA('MainMemory', 'write')_Energy: 0.0
# FFA('GlobalBuffer', 'read')_Energy: 0.221516989963269
# FFA('GlobalBuffer', 'write')_Energy: 6.881068188895299e-05
# FFA('MAC', 'compute')_Energy: 0.01443109011456
# FFARESOURCE_Register_LEVEL_1: nan
# FFARESOURCE_LocalBuffer_LEVEL_1: nan
# FFARESOURCE_GlobalBuffer_LEVEL_1: nan
# FFARESOURCE_Register_LEVEL_0: 8.0
# FFARESOURCE_LocalBuffer_LEVEL_0: 135168.0
# FFARESOURCE_GlobalBuffer_LEVEL_0: 335544320.0
# FFA__MAPPING: type=None nodes=[Storage(type=None, tensors=['Z'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='Z', memory='MainMemory'), Reservation(type=None, tensor='Z', memory='MainMemory'), Storage(type=None, tensors=['WFFA'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WFFA', memory='MainMemory'), Reservation(type=None, tensor='WFFA', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='c', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['Z'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=Non ...
# Z__tile_shape0: 1.0
# Z__tile_shape1: 128.0
# Z__tile_shape2: 32.0
# Z__tile_shape3: 2048.0
# Z__tile_shape4: 1.0
# Z__tile_shape5: 1.0
# Z__tile_shape6: 512.0
# Z__tile_shape7: 32.0
# Z__tile_shape8: 1.0
# Z__tile_shape9: 1.0
# Z__tile_shape10: 1.0
# Z__tile_shape11: 4.0
# Z__tile_shape12: 1.0
# Z__tile_shape13: 1.0
# Z__tile_shape14: 1.0
# Z__tile_shape15: 1.0
# Z__tile_shape16: 1.0
# Z__tile_shape17: 1.0
# Z__tile_shape18: 1.0
# ZRESOURCE_Register_LEVEL_0: 8
# ZRESOURCE_LocalBuffer_LEVEL_0: 135168.0
# ZRESOURCE_GlobalBuffer_LEVEL_0: 67125248.0
# ZRESOURCE_MainMemory_LEVEL_0: 268435456
# Zmetric_Latency: 524288.0
# Zcompute_Latency: 524288.0
# ZRegister_Latency: 0
# ZLocalBuffer_Latency: 0
# ZMainMemory_Latency: 57381.357654600535
# ZGlobalBuffer_Latency: 0
# Zmetric_Energy: 0.10217670544350618
# Z('Register', 'read')_Energy: 0
# Z('Register', 'write')_Energy: 0
# Z('LocalBuffer', 'read')_Energy: 0.0227181840866243
# Z('LocalBuffer', 'write')_Energy: 0.019826975461796875
# Z('MainMemory', 'read')_Energy: 0.0005307472281599999
# Z('MainMemory', 'write')_Energy: 5.897191424e-05
# Z('GlobalBuffer', 'read')_Energy: 0.055392767814911634
# Z('GlobalBuffer', 'write')_Energy: 4.12864091333719e-05
# Z('MAC', 'compute')_Energy: 0.00360777252864
# Z__MAPPING: type=None nodes=[Storage(type=None, tensors=['Z'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='Z', memory='MainMemory'), Reservation(type=None, tensor='Z', memory='MainMemory'), Storage(type=None, tensors=['WZ'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WZ', memory='MainMemory'), Reservation(type=None, tensor='WZ', memory='MainMemory'), Storage(type=None, tensors=['AV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_ ...
# AV__tile_shape0: 1.0
# AV__tile_shape1: 8.0
# AV__tile_shape2: 1.0
# AV__tile_shape3: 128.0
# AV__tile_shape4: 2048.0
# AV__tile_shape5: 1.0
# AV__tile_shape6: 1.0
# AV__tile_shape7: 1.0
# AV__tile_shape8: 2048.0
# AV__tile_shape9: 512.0
# AV__tile_shape10: 32.0
# AV__tile_shape11: 1.0
# AV__tile_shape12: 1.0
# AV__tile_shape13: 1.0
# AV__tile_shape14: 4.0
# AV__tile_shape15: 1.0
# AV__tile_shape16: 1.0
# AV__tile_shape17: 1.0
# AV__tile_shape18: 1.0
# AV__tile_shape19: 1.0
# AV__tile_shape20: 1.0
# AVRESOURCE_Register_LEVEL_2: 8
# AVRESOURCE_LocalBuffer_LEVEL_2: 135168.0
# AVRESOURCE_GlobalBuffer_LEVEL_1: 268435456.0
# AVRESOURCE_GlobalBuffer_LEVEL_2: 285229056.0
# AVRESOURCE_MainMemory_LEVEL_0: 67108864
# AVmetric_Latency: 262144.0
# AVcompute_Latency: 262144.0
# AVLocalBuffer_Latency: 0
# AVRegister_Latency: 0
# AVGlobalBuffer_Latency: 0
# AVMainMemory_Latency: 14345.339413650147
# AVmetric_Energy: 0.05092139758624782
# AV('LocalBuffer', 'read')_Energy: 0.0113590920433122
# AV('LocalBuffer', 'write')_Energy: 0.009914697725739254
# AV('Register', 'read')_Energy: 0
# AV('Register', 'write')_Energy: 0
# AV('GlobalBuffer', 'read')_Energy: 0.027757225365880787
# AV('GlobalBuffer', 'write')_Energy: 2.7524272755581202e-05
# AV('MainMemory', 'read')_Energy: 0.0
# AV('MainMemory', 'write')_Energy: 5.897191424e-05
# AV('MAC', 'compute')_Energy: 0.00180388626432
# AV__MAPPING: type=None nodes=[Storage(type=None, tensors=['AV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='AV', memory='MainMemory'), Reservation(type=None, tensor='AV', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['QK'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='QK', memory='GlobalBuffer'), Reservation(type=None, tensor='QK', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='f', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='p', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['V'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', at ...
# QK__tile_shape0: 1.0
# QK__tile_shape1: 8.0
# QK__tile_shape2: 1.0
# QK__tile_shape3: 128.0
# QK__tile_shape4: 1.0
# QK__tile_shape5: 2048.0
# QK__tile_shape6: 512.0
# QK__tile_shape7: 1.0
# QK__tile_shape8: 1.0
# QK__tile_shape9: 512.0
# QK__tile_shape10: 1.0
# QK__tile_shape11: 32.0
# QK__tile_shape12: 1.0
# QK__tile_shape13: 1.0
# QK__tile_shape14: 4.0
# QK__tile_shape15: 1.0
# QK__tile_shape16: 1.0
# QK__tile_shape17: 1.0
# QK__tile_shape18: 1.0
# QK__tile_shape19: 1.0
# QK__tile_shape20: 1.0
# QK__tile_shape21: 1.0
# QKRESOURCE_Register_LEVEL_3: nan
# QKRESOURCE_LocalBuffer_LEVEL_3: nan
# QKRESOURCE_GlobalBuffer_LEVEL_1: 268435456.0
# QKRESOURCE_GlobalBuffer_LEVEL_3: nan
# QKmetric_Latency: 262144.0
# QKcompute_Latency: 262144.0
# QKLocalBuffer_Latency: 0
# QKRegister_Latency: 0
# QKGlobalBuffer_Latency: 0
# QKmetric_Energy: 0.05107787510242718
# QK('LocalBuffer', 'read')_Energy: 0.0113590920433122
# QK('LocalBuffer', 'write')_Energy: 0.009950997570964074
# QK('Register', 'read')_Energy: 0
# QK('Register', 'write')_Energy: 0
# QK('GlobalBuffer', 'read')_Energy: 0.02774370504178635
# QK('GlobalBuffer', 'write')_Energy: 0.0002201941820446492
# QK('MAC', 'compute')_Energy: 0.00180388626432
# QKRESOURCE_Register_LEVEL_4: nan
# QKRESOURCE_LocalBuffer_LEVEL_4: nan
# QKRESOURCE_GlobalBuffer_LEVEL_4: nan
# QKRESOURCE_GlobalBuffer_LEVEL_2: 301989888.0
# QKRESOURCE_Register_LEVEL_2: 8.0
# QKRESOURCE_LocalBuffer_LEVEL_2: 135168.0
# QK__MAPPING: type=None nodes=[Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['QK'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='QK', memory='GlobalBuffer'), Reservation(type=None, tensor='QK', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['K'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='K', memory='GlobalBuffer'), Reservation(type=None, tensor='K', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', ...
# Q__tile_shape0: 1.0
# Q__tile_shape1: 2048.0
# Q__tile_shape2: 1.0
# Q__tile_shape3: 128.0
# Q__tile_shape4: 8.0
# Q__tile_shape5: 1.0
# Q__tile_shape6: 512.0
# Q__tile_shape7: 1.0
# Q__tile_shape8: 1.0
# Q__tile_shape9: 1.0
# Q__tile_shape10: 512.0
# Q__tile_shape11: 32.0
# Q__tile_shape12: 1.0
# Q__tile_shape13: 1.0
# Q__tile_shape14: 1.0
# Q__tile_shape15: 4.0
# Q__tile_shape16: 1.0
# Q__tile_shape17: 1.0
# Q__tile_shape18: 1.0
# Q__tile_shape19: 1.0
# Q__tile_shape20: 1.0
# Q__tile_shape21: 1.0
# Q__tile_shape22: 1.0
# QRESOURCE_Register_LEVEL_4: nan
# QRESOURCE_LocalBuffer_LEVEL_4: nan
# QRESOURCE_GlobalBuffer_LEVEL_1: nan
# QRESOURCE_GlobalBuffer_LEVEL_4: nan
# QRESOURCE_MainMemory_LEVEL_0: 134217728
# Qmetric_Latency: 524288.0
# Qcompute_Latency: 524288.0
# QRegister_Latency: 0
# QLocalBuffer_Latency: 0
# QMainMemory_Latency: 28690.678827300246
# QGlobalBuffer_Latency: 0
# Qmetric_Energy: 0.1020177170181762
# Q('Register', 'read')_Energy: 0
# Q('Register', 'write')_Energy: 0
# Q('LocalBuffer', 'read')_Energy: 0.0227181840866243
# Q('LocalBuffer', 'write')_Energy: 0.019826975461796868
# Q('MainMemory', 'read')_Energy: 0.00047177531392
# Q('MainMemory', 'write')_Energy: 0.0
# Q('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# Q('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# Q('MAC', 'compute')_Energy: 0.00360777252864
# QRESOURCE_Register_LEVEL_3: nan
# QRESOURCE_LocalBuffer_LEVEL_3: nan
# QRESOURCE_GlobalBuffer_LEVEL_3: nan
# QRESOURCE_Register_LEVEL_2: 8.0
# QRESOURCE_LocalBuffer_LEVEL_2: 135168.0
# QRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# QRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# QRESOURCE_Register_LEVEL_1: nan
# QRESOURCE_LocalBuffer_LEVEL_1: nan
# Q__MAPPING: type=None nodes=[Storage(type=None, tensors=['WQ'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WQ', memory='MainMemory'), Reservation(type=None, tensor='WQ', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['Q'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# K__tile_shape0: 1.0
# K__tile_shape1: 2048.0
# K__tile_shape2: 1.0
# K__tile_shape3: 128.0
# K__tile_shape4: 8.0
# K__tile_shape5: 1.0
# K__tile_shape6: 512.0
# K__tile_shape7: 1.0
# K__tile_shape8: 1.0
# K__tile_shape9: 1.0
# K__tile_shape10: 512.0
# K__tile_shape11: 32.0
# K__tile_shape12: 1.0
# K__tile_shape13: 1.0
# K__tile_shape14: 1.0
# K__tile_shape15: 4.0
# K__tile_shape16: 1.0
# K__tile_shape17: 1.0
# K__tile_shape18: 1.0
# K__tile_shape19: 1.0
# K__tile_shape20: 1.0
# K__tile_shape21: 1.0
# K__tile_shape22: 1.0
# KRESOURCE_Register_LEVEL_4: nan
# KRESOURCE_LocalBuffer_LEVEL_4: nan
# KRESOURCE_GlobalBuffer_LEVEL_1: nan
# KRESOURCE_GlobalBuffer_LEVEL_4: nan
# KRESOURCE_MainMemory_LEVEL_0: 134217728
# Kmetric_Latency: 524288.0
# Kcompute_Latency: 524288.0
# KLocalBuffer_Latency: 0
# KRegister_Latency: 0
# KMainMemory_Latency: 28690.678827300246
# KGlobalBuffer_Latency: 0
# Kmetric_Energy: 0.1020177170181762
# K('LocalBuffer', 'read')_Energy: 0.0227181840866243
# K('LocalBuffer', 'write')_Energy: 0.019826975461796868
# K('Register', 'read')_Energy: 0
# K('Register', 'write')_Energy: 0
# K('MainMemory', 'read')_Energy: 0.00047177531392
# K('MainMemory', 'write')_Energy: 0.0
# K('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# K('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# K('MAC', 'compute')_Energy: 0.00360777252864
# KRESOURCE_Register_LEVEL_3: nan
# KRESOURCE_LocalBuffer_LEVEL_3: nan
# KRESOURCE_GlobalBuffer_LEVEL_3: nan
# KRESOURCE_Register_LEVEL_2: 8.0
# KRESOURCE_LocalBuffer_LEVEL_2: 135168.0
# KRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# KRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# KRESOURCE_Register_LEVEL_1: nan
# KRESOURCE_LocalBuffer_LEVEL_1: nan
# K__MAPPING: type=None nodes=[Storage(type=None, tensors=['WK'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WK', memory='MainMemory'), Reservation(type=None, tensor='WK', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['K'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# V__tile_shape0: 1.0
# V__tile_shape1: 2048.0
# V__tile_shape2: 1.0
# V__tile_shape3: 128.0
# V__tile_shape4: 8.0
# V__tile_shape5: 1.0
# V__tile_shape6: 512.0
# V__tile_shape7: 1.0
# V__tile_shape8: 1.0
# V__tile_shape9: 1.0
# V__tile_shape10: 512.0
# V__tile_shape11: 32.0
# V__tile_shape12: 1.0
# V__tile_shape13: 1.0
# V__tile_shape14: 1.0
# V__tile_shape15: 4.0
# V__tile_shape16: 1.0
# V__tile_shape17: 1.0
# V__tile_shape18: 1.0
# V__tile_shape19: 1.0
# V__tile_shape20: 1.0
# V__tile_shape21: 1.0
# V__tile_shape22: 1.0
# VRESOURCE_Register_LEVEL_4: nan
# VRESOURCE_LocalBuffer_LEVEL_4: nan
# VRESOURCE_GlobalBuffer_LEVEL_1: nan
# VRESOURCE_GlobalBuffer_LEVEL_4: nan
# VRESOURCE_MainMemory_LEVEL_0: 134217728
# Vmetric_Latency: 524288.0
# Vcompute_Latency: 524288.0
# VLocalBuffer_Latency: 0
# VRegister_Latency: 0
# VMainMemory_Latency: 28690.678827300246
# VGlobalBuffer_Latency: 0
# Vmetric_Energy: 0.1020177170181762
# V('LocalBuffer', 'read')_Energy: 0.0227181840866243
# V('LocalBuffer', 'write')_Energy: 0.019826975461796868
# V('Register', 'read')_Energy: 0
# V('Register', 'write')_Energy: 0
# V('MainMemory', 'read')_Energy: 0.00047177531392
# V('MainMemory', 'write')_Energy: 0.0
# V('GlobalBuffer', 'read')_Energy: 0.0553792474908172
# V('GlobalBuffer', 'write')_Energy: 1.37621363777906e-05
# V('MAC', 'compute')_Energy: 0.00360777252864
# VRESOURCE_Register_LEVEL_3: nan
# VRESOURCE_LocalBuffer_LEVEL_3: nan
# VRESOURCE_GlobalBuffer_LEVEL_3: nan
# VRESOURCE_Register_LEVEL_2: 8.0
# VRESOURCE_LocalBuffer_LEVEL_2: 135168.0
# VRESOURCE_GlobalBuffer_LEVEL_2: 83886080.0
# VRESOURCE_GlobalBuffer_LEVEL_0: 67108864.0
# VRESOURCE_Register_LEVEL_1: nan
# VRESOURCE_LocalBuffer_LEVEL_1: nan
# V__MAPPING: type=None nodes=[Storage(type=None, tensors=['WV'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='WV', memory='MainMemory'), Reservation(type=None, tensor='WV', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='e', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='h', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['V'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attrib ...
# I__tile_shape0: 1.0
# I__tile_shape1: 4096.0
# I__tile_shape2: 2048.0
# I__tile_shape3: 1.0
# I__tile_shape4: 2048.0
# I__tile_shape5: 32.0
# I__tile_shape6: 1.0
# I__tile_shape7: 2048.0
# I__tile_shape8: 8.0
# I__tile_shape9: 1.0
# I__tile_shape10: 32.0
# I__tile_shape11: 4.0
# I__tile_shape12: 1.0
# I__tile_shape13: 1.0
# I__tile_shape14: 1.0
# IRESOURCE_LocalBuffer_LEVEL_2: nan
# IRESOURCE_GlobalBuffer_LEVEL_2: nan
# IRESOURCE_MainMemory_LEVEL_0: 67108864
# Imetric_Latency: 128.0
# Icompute_Latency: 128.0
# IGlobalBuffer_Latency: 0
# ILocalBuffer_Latency: 0
# IMainMemory_Latency: 14345.3394136501
# Imetric_Energy: 0.000108510510124215
# I('GlobalBuffer', 'read')_Energy: 1.35203240944378e-05
# I('GlobalBuffer', 'write')_Energy: 2.75242727555812e-05
# I('LocalBuffer', 'read')_Energy: 2.77321583088676e-06
# I('LocalBuffer', 'write')_Energy: 4.83997936330938e-06
# I('MainMemory', 'read')_Energy: 5.897191424e-05
# I('MainMemory', 'write')_Energy: 0.0
# I('MAC', 'compute')_Energy: 8.8080384e-07
# IRESOURCE_LocalBuffer_LEVEL_1: nan
# IRESOURCE_GlobalBuffer_LEVEL_1: nan
# IRESOURCE_LocalBuffer_LEVEL_0: 131072.0
# IRESOURCE_GlobalBuffer_LEVEL_0: 67633152.0
# I__MAPPING: type=None nodes=[Storage(type=None, tensors=['I_in'], memory='MainMemory', memory_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=9999999999999, multiple_buffering=1, shared_read_write_bandwidth=4678.0952380952385, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=4678), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='Q | K | V | I', keep='~Intermediates()', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='DRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=7.03e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I_in', memory='MainMemory'), Reservation(type=None, tensor='I_in', memory='MainMemory'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape0, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='d', loop_bound=None, tile_shape=tileshape1, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape2, tile_pattern=None, assume_perfect_factor=True), Storage(type=None, tensors=['I'], memory='GlobalBuffer', memory_object=Memory(type=None, name='GlobalBuffer', attributes=MemoryAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=1, datawidth=8, size=1073741824, multiple_buffering=1, shared_read_write_bandwidth=inf, read_bandwidth=inf, write_bandwidth=inf, version='0.5', width=8192), spatial=Spatial(type=None, fanout={}), constraints=ConstraintGroup(type=None, name=None, spatial=[], temporal=Temporal(type=None, version='0.5', reuse='All', loop_bounds=[], rmw_first_update=[]), storage=Storage(type=None, bypass='weight - ( ~MainMemory.tensors() | input | output)', keep='~MainMemory.tensors() | input | output', coalesce='All', tile_shape=[]), dataflow=Dataflow(type=None, storage_orders=[])), component_class='SRAM', enabled=True, power_gated_at=None, actions=[SubcomponentAction(type=None, name='read', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6117482297942403e-12, area=None)), SubcomponentAction(type=None, name='write', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=1.6405745002973788e-12, area=None)), SubcomponentAction(type=None, name='leak', arguments=ComponentAttributes(type=None, technology='7nm', global_cycle_seconds=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=0, area=None))])), Fill(type=None, tensor='I', memory='GlobalBuffer'), Reservation(type=None, tensor='I', memory='GlobalBuffer'), Temporal(type=None, rank_variable='b', loop_bound=None, tile_shape=tileshape3, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='d', loop_bound=None, tile_shape=tileshape4, tile_pattern=None, assume_perfect_factor=True), Temporal(type=None, rank_variable='m', loop_bound=None, tile_shape=tileshape5, tile_pattern=None, assume_perfe ...
# metric_Latency: 6815872.0
# metric_Energy: 1.3265898178893936

# %%
from fastfusion.mapper.FFM.exploration.mapper_multi_einsum import get_rank_variable_bounds_for_all_einsums

sram_size = 0.5 * 1024 * 1024 * 8
llb = CactiSRAM(technology="7nm", width=128, depth=sram_size // 128)
mac_dims = int((((area_budget - glb.get_area()) / 4 - llb.get_area()) / mac_area)** 0.5)
mappings = get_fused_mappings(
    spec,
    mac_dims,
    llb,
    glb,
    return_mappings=True,
    parameterization="FFM"
)
mappings._data = mappings.data.sort_values(by="metric_Latency", ascending=True).head()
rank_variable_bounds = get_rank_variable_bounds_for_all_einsums(spec)
from fastfusion.mapper.FFM.visualization import make_mapping
from IPython.display import SVG
newmapping = make_mapping(mappings.data.iloc[0], spec.workload.einsum_names, get_rank_variable_bounds_for_all_einsums(spec))
b = {}
for col in mappings.data.columns:
    print(f'{col}: {mappings.data.iloc[0][col]}')
    if "Latency" in col:
        b[col] = mappings.data.iloc[0][col]
display(SVG(newmapping.render()))
# Out:
# INFO        Calculated "614e9 * 8 / 1.05e9" = 4678.0952380952385.
# INFO        Calculated "0.84e-12 / 8" = 1.05e-13.
# INFO        Calculated "0.5" = 0.5.
# By default metrics optimizes for energy and latency.We should change to just energy or just latency at some point.
# Generating storage and loop choices for Einsum I: 12it [00:00, 143.57it/s]
# Generating Pmappings for I: 100%|██████████| 12/12 [00:00<00:00, 4929.16it/s]
# 0 / 144 skipped (0.00%)
# 0 / 144 skipped (0.00%)
# 0 / 144 skipped (0.00%)
# 0 / 144 skipped (0.00%)
# 0 / 144 skipped (0.00%)
# 0 / 144 skipped (0.00%)
# 0 / 2333 skipped (0.00%)
# 0 / 2333 skipped (0.00%)
# 0 / 2426 skipped (0.00%)
# 0 / 2426 skipped (0.00%)
# 0 / 2426 skipped (0.00%)
# 0 / 2333 skipped (0.00%)
# Generating storage and loop choices for Einsum V: 28it [00:00, 218.87it/s]
# Generating Pmappings for V: 100%|██████████| 28/28 [00:00<00:00, 20956.55it/s]
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# 18 / 481 skipped (3.74%)
# 14 / 228 skipped (6.14%)
# 18 / 481 skipped (3.74%)
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# Skipping Compatibility(loops=(), storage={Reservation('I', 0, 'MainMemory', 0)}), tags=Tags(({})) because it is not in any tensor2boundless_compatibilities
# 481 / 481 skipped (100.00%)
# 481 / 481 skipped (100.00%)
# 48 / 3408 skipped (1.41%)
# 0 / 4416 skipped (0.00%)
# 91629 / 247163 skipped (37.07%)
# 165 / 110346 skipped (0.15%)
# 91629 / 247163 skipped (37.07%)
# 0 / 114698 skipped (0.00%)
# 247163 / 247163 skipped (100.00%)
# 247163 / 247163 skipped (100.00%)

# %%
df = pd.DataFrame([a, b])
df
