# %%
import copy
from fastfusion import Specification
spec = Specification.from_yaml(
    "architecture/four_level.arch.yaml",
    "workloads/mha_full_new.yaml"
)
spec.estimate_energy_area()
spec.component_energy.to_yaml("ERT.yaml")
spec.component_area.to_yaml("ART.yaml")
spec.workload.mermaid_graph() # pip3 install mermaid-py
# Out:
# 2025-05-05 14:36:43 INFO        Loading yaml file architecture/four_level.arch.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file workloads/mha_full_new.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file architecture/four_level.arch.yaml
# 2025-05-05 14:36:43 INFO        Found top key variables in architecture/four_level.arch.yaml
# 2025-05-05 14:36:43 INFO        Found top key architecture in architecture/four_level.arch.yaml
# 2025-05-05 14:36:43 INFO        Found top key compound_components in architecture/four_level.arch.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file workloads/mha_full_new.yaml
# 2025-05-05 14:36:43 INFO        Found top key workload in workloads/mha_full_new.yaml
# 2025-05-05 14:36:43 WARNING     Loading configuration file from /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key version in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key environment_variables in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key expression_custom_functions in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key component_plug_ins in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Parsing extra attributes
# 2025-05-05 14:36:43 INFO        Running processor References2CopiesProcessor
# 2025-05-05 14:36:43 INFO        Processor References2CopiesProcessor done after 0.00 seconds
# 2025-05-05 14:36:43 INFO        Specification processed in 0.00 seconds
# 2025-05-05 14:36:43 INFO        Parsing extra attributes
# 2025-05-05 14:36:43 INFO        Loading plug-ins from /home/plug-ins/neurosim-plug-in/main.py. Errors below are likely due to the plug-in.
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimADC that estimates array_adc with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimAdder that estimates adder with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimAdderTree that estimates adder_tree with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimColDrivers that estimates array_col_drivers with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimFlipFlop that estimates flip_flop with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimMaxPool that estimates max_pool with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimMemoryCell that estimates memory_cell with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimMux that estimates mux with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimNANDGate that estimates nand_gate with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimNORGate that estimates nor_gate with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimNOTGate that estimates not_gate with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimPIMComponent that estimates _override_this_name_ with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimPlugInComponent that estimates _override_this_name_ with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimRowDrivers that estimates array_row_drivers with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NeurosimShiftAdd that estimates shift_add with actions add, compute, convert, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Loading plug-ins from /home/plug-ins/cacti-plug-in/main.py. Errors below are likely due to the plug-in.
# 2025-05-05 14:36:43 INFO        Added estimator CactiCache that estimates cache with actions read, read_access, update, update_access, write, write_access, leak
# 2025-05-05 14:36:43 INFO        Added estimator CactiDRAM that estimates ['DRAM', 'dram'] with actions read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator CactiSRAM that estimates ['SRAM', 'sram'] with actions read, update, write, leak
# 2025-05-05 14:36:43 INFO        Loading plug-ins from /home/plug-ins/adc-plug-in/main.py. Errors below are likely due to the plug-in.
# 2025-05-05 14:36:43 INFO        Added estimator ADCEstimator that estimates ['adc', 'pim_adc', 'sar_adc', 'array_adc', 'pim_array_adc', 'cim_array_adc', 'cim_adc'] with actions activate, convert, drive, read, sample, leak
# 2025-05-05 14:36:43 INFO        Loading plug-ins from /home/plug-ins/library-plug-in/main.py. Errors below are likely due to the plug-in.
# 2025-05-05 14:36:43 INFO        Loaded 133 components from library.
# 2025-05-05 14:36:43 INFO        Added estimator AladdinAdder that estimates aladdin_adder with actions add, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AladdinComparator that estimates aladdin_comparator with actions compare, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AladdinCounter that estimates aladdin_counter with actions count, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AladdinMultiplier that estimates aladdin_multiplier with actions leak, multiply, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AladdinRegister that estimates aladdin_register with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerAdc that estimates atomlayer_adc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerDac that estimates atomlayer_dac with actions drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerEdram that estimates atomlayer_edram with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerEdramBus that estimates atomlayer_edram_bus with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerInputBufferTransfers that estimates atomlayer_input_buffer_transfers with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerRegisterLadder that estimates atomlayer_register_ladder with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerRouter that estimates atomlayer_router with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator AtomlayerShiftAdd that estimates atomlayer_shift_add with actions leak, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator BrahmsDac that estimates brahms_dac with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator DummyCompute that estimates dummy_compute with actions *, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator DummyStorage that estimates dummy_storage with actions *, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator FormsAdc that estimates forms_adc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator FormsDac that estimates forms_dac with actions drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacAdc that estimates isaac_adc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacChip2chipLink that estimates isaac_chip2chip_link with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacDac that estimates isaac_dac with actions drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacEdram that estimates isaac_edram with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacEdramBus that estimates isaac_edram_bus with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacRouter that estimates isaac_router with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacRouterSharedByFour that estimates isaac_router_shared_by_four with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator IsaacShiftAdd that estimates isaac_shift_add with actions leak, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator JiaDatapath that estimates jia_datapath with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator JiaShiftAdd that estimates jia_shift_add with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator JiaZeroGate that estimates jia_zero_gate with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator LibraryEstimatorClassBase that estimates _must_override_name_ with actions leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonAdc that estimates newton_adc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonDac that estimates newton_dac with actions drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonEdram that estimates newton_edram with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonEdramBus that estimates newton_edram_bus with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonRouter that estimates newton_router with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator NewtonShiftAdd that estimates newton_shift_add with actions leak, read, shift_add, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator RaaamEdram that estimates raaam_edram with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator RaellaQuantMultiplier that estimates raella_quant_multiplier with actions leak, multiply, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyChargingComparator that estimates timely_charging_comparator with actions compare, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyChip2chipLink that estimates timely_chip2chip_link with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyDtc that estimates timely_dtc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyIadder that estimates timely_iadder with actions add, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyInputOutputBuffer that estimates timely_input_output_buffer with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyPsubbuf that estimates timely_psubbuf with actions convert, drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyTdc that estimates timely_tdc with actions convert, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator TimelyXsubbuf that estimates timely_xsubbuf with actions buffer, drive, leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator WanAnalogIntegrator that estimates wan_analog_integrator with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator WanAnalogSample that estimates wan_analog_sample with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator WanShiftAdd that estimates wan_shift_add with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 INFO        Added estimator WanVariablePrecisionAdc that estimates wan_variable_precision_adc with actions leak, read, update, write, leak
# 2025-05-05 14:36:43 WARNING     Loading configuration file from /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Loading yaml file /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key version in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key environment_variables in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key expression_custom_functions in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Found top key component_plug_ins in /root/.config/fastfusion/config.yaml
# 2025-05-05 14:36:43 INFO        Parsing extra attributes
# 2025-05-05 14:36:43 INFO        Specification processed in 0.00 seconds
# 2025-05-05 14:36:43 INFO        Calculated Specification[variables].Variables[version] as "0.5" = 0.5.
# 2025-05-05 14:36:43 INFO        Calculated Specification[architecture].Architecture[nodes].ArchNodes[0].Storage(MainMemory)[attributes].StorageAttributes[energy_scale] as "(450 / 64) / 8" = 0.87890625.
# 2025-05-05 14:36:43 INFO        Calculated Specification[architecture].Architecture[nodes].ArchNodes[1].Storage(GlobalBuffer)[attributes].StorageAttributes[size] as "1024*1024*128*8" = 1073741824.
# 2025-05-05 14:36:43 INFO        Calculated Specification[architecture].Architecture[nodes].ArchNodes[2].Storage(LocalBuffer)[attributes].StorageAttributes[size] as "1024*1024*32*8" = 268435456.
# 2025-05-05 14:36:43 INFO        Specification processed in 0.00 seconds
