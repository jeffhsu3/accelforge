# %%
import fastfusion
from fastfusion.mapper import Metrics
import time

import csv

from IPython.display import display, SVG

from paths import ARCH_DIR, WORKLOADS_DIR

# %%
def run_experiment(arch_fname, workload_fname):
    spec = fastfusion.Specification.from_yaml(
        ARCH_DIR / arch_fname,
        WORKLOADS_DIR / workload_fname,
    )
    spec.mapper.ffm.metrics = Metrics.ENERGY | Metrics.LATENCY
    print(spec.mapper.ffm)
    # spec.mapper.ffm.max_fused_loops = 3
    # spec.mapper.ffm.max_fused_loops_per_rank_variable = 1
    start = time.time()
    pmappings = fastfusion.mapper.FFM.make_pmappings(spec)
    mappings = fastfusion.mapper.FFM.join_pmappings(spec, pmappings)
    end = time.time()
    duration = end - start
    return pmappings, mappings, duration

# %%
run_experiment("snowcat.arch.yaml", "mobilenet_test.yaml")
# Out:
# WARNING Loading configuration file from /home/gilbertm/work/venv/fastfusion/config.yaml
# type=None version='0.5' metrics=<Metrics.LATENCY|ENERGY: 3> timeloop_style_even=False force_memory_hierarchy_order=True max_fused_loops_per_rank_variable=1 max_fused_loops=inf max_loops=inf max_loops_minus_ranks=inf can_lower_first_memory=False memory_limit=inf memory_limit_per_process=inf time_limit=inf time_limit_per_pmapping_template=inf
# Generating pmapping templates for compute MAC Einsum PwiseA0: 12it [00:00, 75.08it/s]
# Generating pmapping templates for compute MAC Einsum PwiseB2: 12it [00:00, 81.25it/s]
# Generating pmapping templates for compute MAC Einsum PwiseA1: 24it [00:00, 110.62it/s]
# Generating pmapping templates for compute MAC Einsum PwiseB0: 24it [00:00, 115.66it/s]
# Generating pmapping templates for compute MAC Einsum Dwise0: 126it [00:00, 232.29it/s]
# Generating pmapping templates for compute MAC Einsum Dwise1: 126it [00:00, 228.06it/s]
# ...
