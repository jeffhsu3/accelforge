# %%
import fastfusion
from fastfusion.mapper import Metrics
import time

import csv

from IPython.display import display, SVG

from paths import ARCH_DIR, WORKLOADS_DIR

# %%
def run_experiment(arch_fname, workload_fname):
    spec = fastfusion.Specification.from_yaml(
        ARCH_DIR / arch_fname,
        WORKLOADS_DIR / workload_fname,
    )
    spec.mapper.ffm.metrics = Metrics.ENERGY | Metrics.LATENCY
    print(spec.mapper.ffm)
    # spec.mapper.ffm.max_fused_loops = 3
    # spec.mapper.ffm.max_fused_loops_per_rank_variable = 1
    start = time.time()
    pmappings = fastfusion.mapper.FFM.make_pmappings(spec)
    mappings = fastfusion.mapper.FFM.join_pmappings(spec, pmappings)
    end = time.time()
    duration = end - start
    return pmappings, mappings, duration

# %%
run_experiment("snowcat.arch.yaml", "mobilenet_7.yaml")
# Out:
# WARNING Loading configuration file from /home/gilbertm/work/venv/fastfusion/config.yaml
# Generating pmapping templates for compute MAC Einsum Dwise0: 0it [00:00, ?it/s]]
# Generating pmapping templates for compute MAC Einsum PwiseA0: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MAC Einsum PwiseA1: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MAC Einsum PwiseB2: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MAC Einsum PwiseB0: 0it [00:00, ?it/s]
# Generating pmapping templates for compute MAC Einsum Dwise1: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_multi_einsum.py", line 105, in make_jobs_for_einsum
#     for j in get_single_einsum_jobs(job):
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_one_einsum/pmapping_template_generator.py", line 371, in get_single_einsum_jobs
#     for i, (mapping, constraints, symbol_table) in enumerate(mappings_constraints):
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_one_einsum/pmapping_template_generator.py", line 264, in iterate_mappings_constraints
#     for mapping, symbol_table in iterate_mappings_no_constraints(
#   File "/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_one_einsum/pmapping_template_generator.py", line 232, in iterate_mappings_no_constraints
#     spec.mapper.ffm.can_lower_first_memory,
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/gilbertm/work/venv/lib/python3.12/site-packages/pydantic/main.py", line 991, in __getattr__
#     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
# AttributeError: 'FFM' object has no attribute 'can_lower_first_memory'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 run_experiment("snowcat.arch.yaml", "mobilenet_7.yaml")
#
# Cell In[25], line 10, in run_experiment(arch_fname, workload_fname)
#       7 # spec.mapper.ffm.max_fused_loops = 3
#       8 # spec.mapper.ffm.max_fused_loops_per_rank_variable = 1
#       9 start = time.time()
# ---> 10 pmappings = fastfusion.mapper.FFM.make_pmappings(spec)
#      11 mappings = fastfusion.mapper.FFM.join_pmappings(spec, pmappings)
#      12 end = time.time()
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_interface/main.py:111, in make_pmappings(spec, einsum_names, can_combine_multiple_runs, cache_dir, print_number_of_pmappings)
#     107 assert len(kwargs) == len(inspect.signature(_make_pmappings).parameters)
#     110 if cache_dir is None:
# --> 111     result = _make_pmappings(**kwargs)
#     112 else:
#     113     @joblib.Memory(location=os.path.join(cache_dir), compress=True).cache
#     114     def _make_pmappings_cached(**kwargs) -> MultiEinsumPmappings:
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_interface/main.py:53, in _make_pmappings(spec, einsum_names, can_combine_multiple_runs)
#      51 parsed_spec.calculate_component_energy_area(area=False)
#      52 flattened_arches = parsed_spec.get_flattened_architecture()
# ---> 53 sims, pmapping_objects, einsum2jobs = get_sims(
#      54     parsed_spec,
#      55     flattened_arches,
#      56     metrics=spec.mapper.ffm.metrics,
#      57     einsum_names=einsum_names,
#      58     can_combine_multiple_runs=can_combine_multiple_runs,
#      59 )
#      60 resource2capacity = {}
#      61 for flattened_arch in flattened_arches:
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_multi_einsum.py:253, in get_sims(spec, flattened_arches, can_combine_multiple_runs, metrics, einsum_names, fail_if_no_pmappings_for_einsum)
#     250     fail_if_no_pmappings_for_einsum = not can_combine_multiple_runs
#     252 einsum2jobs = {}
# --> 253 new_einsum2jobs = get_jobs(
#     254     spec,
#     255     flattened_arches,
#     256     metrics,
#     257     einsum_names,
#     258     fail_if_no_pmappings_for_einsum,
#     259 )
#     260 _fill_jobs_with_memories_to_track(
#     261     new_einsum2jobs, spec, flattened_arches, metrics, can_combine_multiple_runs
#     262 )
#     263 for einsum_name, jobs in new_einsum2jobs.items():
#
# File ~/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_multi_einsum.py:111, in get_jobs(spec, flattened_arches, metrics, einsum_names, fail_if_no_pmappings_for_einsum)
#     108     return einsum_name, jobs
#     110 einsum2jobs = {}
# --> 111 for einsum_name, jobs in parallel(
#     112     [
#     113         delayed(make_jobs_for_einsum)(einsum_name, flattened_arch)
#     114         for einsum_name in einsum_names
#     115         for flattened_arch in flattened_arches
#     116     ],
#     117     pbar="Generating jobs",
#     118     return_as="generator",
#     119 ):
#     120     # n_jobs = sum(len(j) for j in jobs.values())
#     121     # print(f"Generated {n_jobs} job{'s'[:n_jobs != 1]} for {einsum_name}")
#     122     einsum2jobs.setdefault(einsum_name, {})
#     123     for compatibility, job_list in jobs.items():
#
# File ~/work/active/fastfusion/fastfusion/util/util.py:138, in parallel.<locals>.yield_results()
#     137 def yield_results():
# --> 138     for result in Parallel(n_jobs=n_jobs, **args)(jobs):
#     139         if pbar:
#     140             pbar.update(1)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File ~/work/venv/lib/python3.12/site-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# AttributeError: 'FFM' object has no attribute 'can_lower_first_memory'
