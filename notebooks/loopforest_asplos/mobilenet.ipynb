# %%
import fastfusion
from fastfusion.util import set_n_parallel_jobs
from fastfusion.mapper import Metrics
import time

import csv

from IPython.display import display, SVG

from paths import ARCH_DIR, WORKLOADS_DIR

# %%
def make_spec(arch_fname, workload_fname):
    spec = fastfusion.Specification.from_yaml(
        ARCH_DIR / arch_fname,
        WORKLOADS_DIR / workload_fname,
    )
    spec.mapper.ffm.metrics = Metrics.ENERGY | Metrics.LATENCY
    # spec.mapper.ffm.max_fused_loops = 3
    spec.mapper.ffm.max_fused_loops_per_rank_variable = 1
    return spec

def run_make_pmappings(spec):
    start = time.time()
    pmappings = fastfusion.mapper.FFM.make_pmappings(spec)
    end = time.time()
    duration = end - start
    return pmappings, duration

def run_join_pmappings(spec, pmappings):
    start = time.time()
    mappings = fastfusion.mapper.FFM.join_pmappings(spec, pmappings)
    end = time.time()
    duration = end - start
    return mappings, duration

# %%
spec = make_spec("snowcat.arch.yaml", "mobilenet_7.yaml")
# Out:
# WARNING Loading configuration file from /home/gilbertm/work/venv/fastfusion/config.yaml

# %%
set_n_parallel_jobs(12)
pmappings, make_duration = run_make_pmappings(spec)
# Out:
# Generating pmapping templates for compute MAC Einsum PwiseB2: 12it [00:00, 74.45it/s]
# Generating pmapping templates for compute MAC Einsum PwiseA0: 12it [00:00, 71.63it/s]
# Generating pmapping templates for compute MAC Einsum PwiseA1: 24it [00:00, 111.29it/s]
# Generating pmapping templates for compute MAC Einsum PwiseB0: 24it [00:00, 106.29it/s]
# Generating pmapping templates for compute MAC Einsum Dwise1: 126it [00:00, 276.13it/s]
# Generating pmapping templates for compute MAC Einsum Dwise0: 126it [00:00, 289.02it/s]
# Generating jobs: 100%|██████████| 6/6 [00:01<00:00,  3.24it/s]
# WARNING Einsum PwiseA0 has 12 pmapping templates:
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [T0 in GlobalBuffer] T-t0  [TA0 in GlobalBuffer] T-n0,t0  [WA0 in GlobalBuffer] T-p0,q0  MAC computes PwiseA0
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [T0 in GlobalBuffer] T-t0  [WA0 in GlobalBuffer] T-p0,q0  [TA0 in GlobalBuffer] T-n0,p0,q0,t0  MAC computes PwiseA0
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [TA0 in GlobalBuffer] T-n0,p0,q0  [T0 in GlobalBuffer] T-t0  [WA0 in GlobalBuffer] T-p0,q0  MAC computes PwiseA0
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [TA0 in GlobalBuffer] T-n0,t0  [WA0 in GlobalBuffer] T-p0,q0  [T0 in GlobalBuffer] T-t0  MAC computes PwiseA0
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [WA0 in GlobalBuffer] T-p0,q0  [T0 in GlobalBuffer] T-t0  [TA0 in GlobalBuffer] T-n0,p0,q0,t0  MAC computes PwiseA0
# WARNING 	[WA0,T0 in MainMemory] T-p0,q0,t0  [WA0 in GlobalBuffer] T-p0,q0  [TA0 in GlobalBuffer] T-n0,p0,q0  [T0 in GlobalBuffer] T-t0  MAC computes PwiseA0
1 in GlobalBuffer] T-p2,q2  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  [TB1 in GlobalBuffer] T-r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  [TB1 in GlobalBuffer] T-r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  [TB1 in GlobalBuffer] T-r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-r1,s1  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-r1,s1  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-r1,s1  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  MAC computes Dwise1
# WARNING 	[WAB1,TB1,TA1 in MainMemory] T-p2,q2,r1,s1,t1  [WAB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-r1,s1  [TA1 in GlobalBuffer] T-p2,q2,r1,s1  MAC computes Dwise1
# WARNING Einsum PwiseB2 has 12 pmapping templates:
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [T2 in GlobalBuffer] T-t1  [TB1 in GlobalBuffer] T-n2,t1  [WB1 in GlobalBuffer] T-p2,q2  MAC computes PwiseB2
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [T2 in GlobalBuffer] T-t1  [WB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-n2,p2,q2,t1  MAC computes PwiseB2
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [TB1 in GlobalBuffer] T-n2,p2,q2  [T2 in GlobalBuffer] T-t1  [WB1 in GlobalBuffer] T-p2,q2  MAC computes PwiseB2
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [TB1 in GlobalBuffer] T-n2,t1  [WB1 in GlobalBuffer] T-p2,q2  [T2 in GlobalBuffer] T-t1  MAC computes PwiseB2
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [WB1 in GlobalBuffer] T-p2,q2  [T2 in GlobalBuffer] T-t1  [TB1 in GlobalBuffer] T-n2,p2,q2,t1  MAC computes PwiseB2
# WARNING 	[WB1,T2 in MainMemory] T-p2,q2,t1  [WB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-n2,p2,q2  [T2 in GlobalBuffer] T-t1  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-n2,p2,q2  [T2 in GlobalBuffer] T-t1  [TB1 in GlobalBuffer] T-n2  [WB1 in GlobalBuffer] T-p2,q2  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-n2,p2,q2  [T2 in GlobalBuffer] T-t1  [WB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-n2  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-p2,q2,t1  [TB1 in GlobalBuffer] T-n2  [T2 in GlobalBuffer] T-t1  [WB1 in GlobalBuffer] T-p2,q2  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-p2,q2,t1  [TB1 in GlobalBuffer] T-n2  [WB1 in GlobalBuffer] T-p2,q2  [T2 in GlobalBuffer] T-t1  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-n2,t1  [WB1 in GlobalBuffer] T-p2,q2  [T2 in GlobalBuffer] T-t1  [TB1 in GlobalBuffer] T-n2  MAC computes PwiseB2
# WARNING 	[WB1,TB1,T2 in MainMemory] T-n2,t1  [WB1 in GlobalBuffer] T-p2,q2  [TB1 in GlobalBuffer] T-n2  [T2 in GlobalBuffer] T-t1  MAC computes PwiseB2
# Generating pmappings:  27%|██▋       | 25/92 [00:11<00:13,  5.10it/s]/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_make_pmappings/mapper_one_einsum/mapper_one_einsum.py:478: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["fused_loop_indices"] = get_fused_loop_indices(
# Generating pmappings: 100%|██████████| 92/92 [00:17<00:00,  5.13it/s]
# Grouping pmappings for PwiseA0: 100%|██████████| 22/22 [00:00<00:00, 476.92it/s]
# Grouping pmappings for Dwise0:   0%|          | 0/121 [00:00<?, ?it/s]/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# Grouping pmappings for Dwise0: 100%|██████████| 121/121 [00:00<00:00, 406.47it/s]
# Grouping pmappings for PwiseB0: 100%|██████████| 78/78 [00:00<00:00, 632.72it/s]
# Grouping pmappings for PwiseA1: 100%|██████████| 78/78 [00:00<00:00, 708.04it/s]
# Grouping pmappings for Dwise1:   0%|          | 0/67 [00:00<?, ?it/s]/home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_pmapping_group/pmapping_group.py:671: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   concatenated.fillna(0),
# Grouping pmappings for Dwise1: 100%|██████████| 67/67 [00:00<00:00, 450.45it/s]
# Grouping pmappings for PwiseB2: 100%|██████████| 22/22 [00:00<00:00, 249.80it/s]
# Dwise1: 6.12e04 total, 3.84e04 (1/2) valid, 8.45e04 (1/1) evaluated, 1.38e03 (1/45) Pareto-Optimal
# Dwise0: 1.34e05 total, 7.85e04 (1/2) valid, 1.31e05 (1/1) evaluated, 3.70e03 (1/36) Pareto-Optimal
# PwiseA0: 8.05e03 total, 3.71e03 (1/2) valid, 4.58e03 (1/2) evaluated, 621 (1/13) Pareto-Optimal
# PwiseB0: 1.15e04 total, 6.33e03 (1/2) valid, 9.06e03 (1/1) evaluated, 1.58e03 (1/7) Pareto-Optimal
# PwiseA1: 1.15e04 total, 6.33e03 (1/2) valid, 9.06e03 (1/1) evaluated, 1.58e03 (1/7) Pareto-Optimal
# PwiseB2: 8.18e03 total, 3.84e03 (1/2) valid, 4.71e03 (1/2) evaluated, 621 (1/13) Pareto-Optimal
# Total: 2.35e05 total, 1.37e05 (1/2) valid, 2.42e05 (1/1) evaluated, 9.47e03 (1/25) Pareto-Optimal

# %%
import pickle

with open("pmappings.pkl", "wb") as f:
    pickle.dump(pmappings, f)

# %%
for sims in pmappings.einsum2pmappings.values():
    for sim in sims:
        data = sim.mappings._data
        if not (data["Total<SEP>energy"] > 0).all():
            iteration_cols = [c for c in data.columns if 'n_iterations' in c]
            print(data["Total<SEP>energy"])
            print(data[iteration_cols])
            iteration_cols = [c for c in data.columns if 'stride' in c]
            print(data[iteration_cols])
            iteration_cols = [c for c in data.columns if 'initial' in c]
            print(data[iteration_cols])

# %%
# import pickle
# with open("pmappings.pkl", "rb") as f:
#     pmappings = pickle.load(f)
mappings, join_duration = run_join_pmappings(spec, pmappings)
# Out:
# Einsum PwiseA0 has 621 pmappings with 37 compatibilities
# Einsum Dwise0 has 3696 pmappings with 178 compatibilities
# Einsum PwiseB0 has 1577 pmappings with 129 compatibilities
# Einsum PwiseA1 has 1577 pmappings with 129 compatibilities
# Einsum Dwise1 has 1376 pmappings with 84 compatibilities
# Einsum PwiseB2 has 621 pmappings with 37 compatibilities
# Compressing pmappings: 100%|██████████| 6/6 [00:00<00:00, 19.91it/s]
# Not tracking GlobalBuffer because it is never reserved for multiple pmappings.
# Not tracking MainMemory because it is never reserved for multiple pmappings.
# Removing unneeded reservations for PwiseA0: 100%|██████████| 74/74 [00:00<00:00, 2180.97it/s]
# Removing unneeded reservations for Dwise0: 100%|██████████| 356/356 [00:00<00:00, 2767.14it/s]
# Removing unneeded reservations for PwiseB0: 100%|██████████| 258/258 [00:00<00:00, 2218.23it/s]
# Removing unneeded reservations for PwiseA1: 100%|██████████| 258/258 [00:00<00:00, 2416.21it/s]
# Removing unneeded reservations for Dwise1: 100%|██████████| 168/168 [00:00<00:00, 372.93it/s]
# Removing unneeded reservations for PwiseB2: 100%|██████████| 74/74 [00:00<00:00, 2284.70it/s]
# Grouping pmappings for Dwise0 (2/6): 100%|██████████| 178/178 [00:00<00:00, 1337.29it/s]
# Grouping pmappings for PwiseB0 (3/6): 100%|██████████| 129/129 [00:00<00:00, 1595.67it/s]
# Grouping pmappings for PwiseA1 (4/6): 100%|██████████| 129/129 [00:00<00:00, 1583.49it/s]
# Grouping pmappings for Dwise1 (5/6): 100%|██████████| 84/84 [00:00<00:00, 1356.31it/s]
# Grouping pmappings for PwiseB2 (6/6): 100%|██████████| 37/37 [00:00<00:00, 397.57it/s]
# Grouping pmappings: 100%|██████████| 37/37 [00:00<00:00, 1067.77it/s]
# Grouping pmappings: 100%|██████████| 18/18 [00:00<00:00, 728.16it/s]/100 [00:00<00:00, 565.78it/s]
# Merging pmappings for PwiseA0 <--> Dwise0 (2/6): 100%|██████████| 100/100 [00:00<00:00, 492.91it/s]
# Grouping pmappings: 100%|██████████| 23/23 [00:00<00:00, 617.29it/s]
# Merging pmappings for Dwise0 <--> PwiseB0 (3/6): 100%|██████████| 244/244 [00:00<00:00, 1071.46it/s]
# Grouping pmappings: 100%|██████████| 9/9 [00:00<00:00, 208.14it/s] 197/260 [00:00<00:00, 1837.17it/s]
# Merging pmappings for PwiseB0 <--> PwiseA1 (4/6): 100%|██████████| 260/260 [00:00<00:00, 1135.30it/s]
# Grouping pmappings: 100%|██████████| 18/18 [00:00<00:00, 794.30it/s]
# Merging pmappings for PwiseA1 <--> Dwise1 (5/6): 100%|██████████| 100/100 [00:00<00:00, 839.93it/s]
# Final consolidate: 100%|██████████| 92/92 [00:00<00:00, 2771.04it/s]
# Grouping pmappings: 100%|██████████| 1/1 [00:01<00:00,  1.93s/it]
# Merging pmappings for Dwise1 <--> PwiseB2 (6/6): 100%|██████████| 92/92 [00:02<00:00, 45.33it/s]
# /home/gilbertm/work/active/fastfusion/fastfusion/mapper/FFM/_interface/main.py:162: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   joined._data = joined.data.fillna(0).reset_index(drop=True)

# %%
data = mappings.data
for a, b in data.iloc[0].items():
    print(a, b)
# Out:
# tensor<SEP>TA0 49
# Total<SEP>latency 0.03847872
# Total<SEP>energy 808800.0
# tensor<SEP>TB0 47040
# tensor<SEP>T1 1
# tensor<SEP>TA1 47040
# tensor<SEP>TB1 49
# PwiseA0<SEP>stride0 7
# PwiseA0<SEP>stride1 7
# PwiseA0<SEP>stride2 960
# PwiseA0<SEP>stride3 1.0
# PwiseA0<SEP>stride4 7.0
# PwiseA0<SEP>stride5 7.0
# PwiseA0<SEP>latency<SEP>compute 0.0075264
# PwiseA0<SEP>first_latency<SEP>MAC<SEP>13 7840.0
# PwiseA0<SEP>latency<SEP>GlobalBuffer 0
# PwiseA0<SEP>latency<SEP>MainMemory 0
# PwiseA0<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# PwiseA0<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# PwiseA0<SEP>energy<SEP>MainMemory<SEP>read 161440.0
# PwiseA0<SEP>energy<SEP>MainMemory<SEP>write 0
# PwiseA0<SEP>energy<SEP>MAC<SEP>compute 0
# PwiseA0<SEP>energy<SEP>MainMemory<SEP>leak 0
# PwiseA0<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# PwiseA0<SEP>energy<SEP>MAC<SEP>leak 0
# PwiseA0<SEP>n_iterations<SEP>0 1.0
# PwiseA0<SEP>lower_iterations<SEP>0 0
# PwiseA0<SEP>stride<SEP>P0<SEP>0 7
# PwiseA0<SEP>initial<SEP>P0<SEP>0 7
# PwiseA0<SEP>n_iterations<SEP>1 1.0
# PwiseA0<SEP>lower_iterations<SEP>1 0
# PwiseA0<SEP>stride<SEP>Q0<SEP>1 7
# PwiseA0<SEP>initial<SEP>Q0<SEP>1 7
# PwiseA0<SEP>n_iterations<SEP>2 1.0
# PwiseA0<SEP>lower_iterations<SEP>2 0
# PwiseA0<SEP>stride<SEP>T0<SEP>2 960
# PwiseA0<SEP>initial<SEP>T0<SEP>2 960
# PwiseA0<SEP>n_iterations<SEP>3 960.0
# PwiseA0<SEP>lower_iterations<SEP>3 959.0
# PwiseA0<SEP>stride<SEP>T0<SEP>3 1
# PwiseA0<SEP>initial<SEP>T0<SEP>3 1.0
# PwiseA0<SEP>n_iterations<SEP>4 1.0
# PwiseA0<SEP>lower_iterations<SEP>4 0.0
# PwiseA0<SEP>stride<SEP>P0<SEP>4 7
# PwiseA0<SEP>initial<SEP>P0<SEP>4 7.0
# PwiseA0<SEP>n_iterations<SEP>5 1.0
# PwiseA0<SEP>lower_iterations<SEP>5 0.0
# PwiseA0<SEP>stride<SEP>Q0<SEP>5 7
# PwiseA0<SEP>initial<SEP>Q0<SEP>5 7.0
# PwiseA0<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WA0'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# PwiseA0<SEP>stride<SEP>P0<SEP>3 0
# PwiseA0<SEP>initial<SEP>P0<SEP>3 0.0
# PwiseA0<SEP>stride<SEP>Q0<SEP>4 0
# PwiseA0<SEP>initial<SEP>Q0<SEP>4 0.0
# PwiseA0<SEP>stride<SEP>T0<SEP>5 0
# PwiseA0<SEP>initial<SEP>T0<SEP>5 0.0
# PwiseA0<SEP>first_latency<SEP>MAC<SEP>10 0.0
# PwiseA0<SEP>first_latency<SEP>MAC<SEP>6 0.0
# PwiseA0<SEP>first_latency<SEP>MAC<SEP>9 0.0
# Dwise0<SEP>stride0 960
# Dwise0<SEP>stride1 1
# Dwise0<SEP>stride2 7.0
# Dwise0<SEP>stride3 7.0
# Dwise0<SEP>latency<SEP>compute 0.00042336
# Dwise0<SEP>first_latency<SEP>MAC<SEP>5 441.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>2 423360.0
# Dwise0<SEP>latency<SEP>GlobalBuffer 0
# Dwise0<SEP>latency<SEP>MainMemory 0
# Dwise0<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# Dwise0<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# Dwise0<SEP>energy<SEP>MainMemory<SEP>read 8640.0
# Dwise0<SEP>energy<SEP>MainMemory<SEP>write 0
# Dwise0<SEP>energy<SEP>MAC<SEP>compute 0
# Dwise0<SEP>energy<SEP>MainMemory<SEP>leak 0
# Dwise0<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# Dwise0<SEP>energy<SEP>MAC<SEP>leak 0
# Dwise0<SEP>n_iterations<SEP>0 1.0
# Dwise0<SEP>lower_iterations<SEP>0 0
# Dwise0<SEP>stride<SEP>T0<SEP>0 960
# Dwise0<SEP>initial<SEP>T0<SEP>0 960
# Dwise0<SEP>n_iterations<SEP>1 960.0
# Dwise0<SEP>lower_iterations<SEP>1 959
# Dwise0<SEP>stride<SEP>T0<SEP>1 1
# Dwise0<SEP>initial<SEP>T0<SEP>1 1
# Dwise0<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WAB0'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# Dwise0<SEP>stride4 0.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>6 0.0
# Dwise0<SEP>initial2 0.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>16 0.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>7 0.0
# Dwise0<SEP>n_iterations<SEP>2 0.0
# Dwise0<SEP>lower_iterations<SEP>2 0.0
# Dwise0<SEP>stride<SEP>P0<SEP>2 0
# Dwise0<SEP>initial<SEP>P0<SEP>2 0.0
# Dwise0<SEP>stride<SEP>P1<SEP>2 0
# Dwise0<SEP>initial<SEP>P1<SEP>2 0.0
# Dwise0<SEP>stride<SEP>R0<SEP>2 0
# Dwise0<SEP>initial<SEP>R0<SEP>2 0.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>9 0.0
# Dwise0<SEP>first_latency<SEP>MAC<SEP>8 0.0
# Dwise0<SEP>stride<SEP>Q0<SEP>2 0
# Dwise0<SEP>initial<SEP>Q0<SEP>2 0.0
# Dwise0<SEP>stride<SEP>S0<SEP>2 0
# Dwise0<SEP>initial<SEP>S0<SEP>2 0.0
# Dwise0<SEP>stride<SEP>Q1<SEP>2 0
# Dwise0<SEP>initial<SEP>Q1<SEP>2 0.0
# PwiseB0<SEP>stride0 7
# PwiseB0<SEP>stride1 7
# PwiseB0<SEP>stride2 7
# PwiseB0<SEP>stride3 7
# PwiseB0<SEP>stride4 1
# PwiseB0<SEP>stride5 1.0
# PwiseB0<SEP>stride6 1.0
# PwiseB0<SEP>latency<SEP>compute 0.0075264
# PwiseB0<SEP>first_latency<SEP>MAC<SEP>12 960.0
# PwiseB0<SEP>first_latency<SEP>MAC<SEP>3 0.0
# PwiseB0<SEP>latency<SEP>GlobalBuffer 0
# PwiseB0<SEP>latency<SEP>MainMemory 0
# PwiseB0<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# PwiseB0<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# PwiseB0<SEP>energy<SEP>MainMemory<SEP>read 153600.0
# PwiseB0<SEP>energy<SEP>MainMemory<SEP>write 0
# PwiseB0<SEP>energy<SEP>MAC<SEP>compute 0
# PwiseB0<SEP>energy<SEP>MainMemory<SEP>leak 0
# PwiseB0<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# PwiseB0<SEP>energy<SEP>MAC<SEP>leak 0
# PwiseB0<SEP>n_iterations<SEP>0 1.0
# PwiseB0<SEP>lower_iterations<SEP>0 0
# PwiseB0<SEP>stride<SEP>P1<SEP>0 7
# PwiseB0<SEP>initial<SEP>P1<SEP>0 7
# PwiseB0<SEP>n_iterations<SEP>1 1.0
# PwiseB0<SEP>lower_iterations<SEP>1 0
# PwiseB0<SEP>stride<SEP>Q1<SEP>1 7
# PwiseB0<SEP>initial<SEP>Q1<SEP>1 7
# PwiseB0<SEP>n_iterations<SEP>2 1.0
# PwiseB0<SEP>lower_iterations<SEP>2 0
# PwiseB0<SEP>stride<SEP>N1<SEP>2 0
# PwiseB0<SEP>initial<SEP>N1<SEP>2 0.0
# PwiseB0<SEP>n_iterations<SEP>3 1.0
# PwiseB0<SEP>lower_iterations<SEP>3 0
# PwiseB0<SEP>stride<SEP>P1<SEP>3 0
# PwiseB0<SEP>initial<SEP>P1<SEP>3 0.0
# PwiseB0<SEP>n_iterations<SEP>4 160.0
# PwiseB0<SEP>lower_iterations<SEP>4 159
# PwiseB0<SEP>stride<SEP>Q1<SEP>4 0
# PwiseB0<SEP>initial<SEP>Q1<SEP>4 0.0
# PwiseB0<SEP>n_iterations<SEP>5 7.0
# PwiseB0<SEP>lower_iterations<SEP>5 6.0
# PwiseB0<SEP>stride<SEP>P1<SEP>5 1
# PwiseB0<SEP>initial<SEP>P1<SEP>5 1.0
# PwiseB0<SEP>n_iterations<SEP>6 7.0
# PwiseB0<SEP>lower_iterations<SEP>6 6.0
# PwiseB0<SEP>stride<SEP>Q1<SEP>6 1
# PwiseB0<SEP>initial<SEP>Q1<SEP>6 1.0
# PwiseB0<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WB0'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# PwiseB0<SEP>first_latency<SEP>MAC<SEP>7 7526400.0
# PwiseB0<SEP>stride<SEP>P1<SEP>2 7
# PwiseB0<SEP>initial<SEP>P1<SEP>2 7.0
# PwiseB0<SEP>stride<SEP>Q1<SEP>3 7
# PwiseB0<SEP>initial<SEP>Q1<SEP>3 7.0
# PwiseB0<SEP>stride<SEP>N1<SEP>4 1
# PwiseB0<SEP>initial<SEP>N1<SEP>4 1.0
# PwiseB0<SEP>first_latency<SEP>MAC<SEP>8 0.0
# PwiseA1<SEP>stride0 7
# PwiseA1<SEP>stride1 7
# PwiseA1<SEP>stride2 7
# PwiseA1<SEP>stride3 7
# PwiseA1<SEP>stride4 1
# PwiseA1<SEP>stride5 1.0
# PwiseA1<SEP>stride6 1.0
# PwiseA1<SEP>latency<SEP>compute 0.0075264
# PwiseA1<SEP>first_latency<SEP>MAC<SEP>12 960.0
# PwiseA1<SEP>first_latency<SEP>MAC<SEP>3 0.0
# PwiseA1<SEP>latency<SEP>GlobalBuffer 0
# PwiseA1<SEP>latency<SEP>MainMemory 0
# PwiseA1<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# PwiseA1<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# PwiseA1<SEP>energy<SEP>MainMemory<SEP>read 153600.0
# PwiseA1<SEP>energy<SEP>MainMemory<SEP>write 0
# PwiseA1<SEP>energy<SEP>MAC<SEP>compute 0
# PwiseA1<SEP>energy<SEP>MainMemory<SEP>leak 0
# PwiseA1<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# PwiseA1<SEP>energy<SEP>MAC<SEP>leak 0
# PwiseA1<SEP>n_iterations<SEP>0 1.0
# PwiseA1<SEP>lower_iterations<SEP>0 0
# PwiseA1<SEP>stride<SEP>P1<SEP>0 7
# PwiseA1<SEP>initial<SEP>P1<SEP>0 7
# PwiseA1<SEP>n_iterations<SEP>1 1.0
# PwiseA1<SEP>lower_iterations<SEP>1 0
# PwiseA1<SEP>stride<SEP>Q1<SEP>1 7
# PwiseA1<SEP>initial<SEP>Q1<SEP>1 7
# PwiseA1<SEP>n_iterations<SEP>2 1.0
# PwiseA1<SEP>lower_iterations<SEP>2 0
# PwiseA1<SEP>stride<SEP>N1<SEP>2 0
# PwiseA1<SEP>initial<SEP>N1<SEP>2 0.0
# PwiseA1<SEP>n_iterations<SEP>3 1.0
# PwiseA1<SEP>lower_iterations<SEP>3 0
# PwiseA1<SEP>stride<SEP>P1<SEP>3 0
# PwiseA1<SEP>initial<SEP>P1<SEP>3 0.0
# PwiseA1<SEP>n_iterations<SEP>4 160.0
# PwiseA1<SEP>lower_iterations<SEP>4 159
# PwiseA1<SEP>stride<SEP>Q1<SEP>4 0
# PwiseA1<SEP>initial<SEP>Q1<SEP>4 0.0
# PwiseA1<SEP>n_iterations<SEP>5 7.0
# PwiseA1<SEP>lower_iterations<SEP>5 6.0
# PwiseA1<SEP>stride<SEP>P1<SEP>5 1
# PwiseA1<SEP>initial<SEP>P1<SEP>5 1.0
# PwiseA1<SEP>n_iterations<SEP>6 7.0
# PwiseA1<SEP>lower_iterations<SEP>6 6.0
# PwiseA1<SEP>stride<SEP>Q1<SEP>6 1
# PwiseA1<SEP>initial<SEP>Q1<SEP>6 1.0
# PwiseA1<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WA1'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# PwiseA1<SEP>first_latency<SEP>MAC<SEP>7 7526400.0
# PwiseA1<SEP>stride<SEP>P1<SEP>2 7
# PwiseA1<SEP>initial<SEP>P1<SEP>2 7.0
# PwiseA1<SEP>stride<SEP>Q1<SEP>3 7
# PwiseA1<SEP>initial<SEP>Q1<SEP>3 7.0
# PwiseA1<SEP>stride<SEP>N1<SEP>4 1
# PwiseA1<SEP>initial<SEP>N1<SEP>4 1.0
# PwiseA1<SEP>first_latency<SEP>MAC<SEP>8 0.0
# Dwise1<SEP>stride0 960
# Dwise1<SEP>initial1 7
# Dwise1<SEP>stride1 7
# Dwise1<SEP>initial2 7
# Dwise1<SEP>stride2 7
# Dwise1<SEP>stride3 1
# Dwise1<SEP>stride4 7.0
# Dwise1<SEP>stride5 7.0
# Dwise1<SEP>latency<SEP>compute 0.00042335999999999996
# Dwise1<SEP>first_latency<SEP>MAC<SEP>11 441.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>2 423360.0
# Dwise1<SEP>latency<SEP>GlobalBuffer 0
# Dwise1<SEP>latency<SEP>MainMemory 0
# Dwise1<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# Dwise1<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# Dwise1<SEP>energy<SEP>MainMemory<SEP>read 8640.0
# Dwise1<SEP>energy<SEP>MainMemory<SEP>write 0
# Dwise1<SEP>energy<SEP>MAC<SEP>compute 0
# Dwise1<SEP>energy<SEP>MainMemory<SEP>leak 0
# Dwise1<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# Dwise1<SEP>energy<SEP>MAC<SEP>leak 0
# Dwise1<SEP>n_iterations<SEP>0 1.0
# Dwise1<SEP>lower_iterations<SEP>0 0
# Dwise1<SEP>stride<SEP>T1<SEP>0 960
# Dwise1<SEP>initial<SEP>T1<SEP>0 960
# Dwise1<SEP>n_iterations<SEP>1 1.0
# Dwise1<SEP>lower_iterations<SEP>1 0
# Dwise1<SEP>stride<SEP>P1<SEP>1 7
# Dwise1<SEP>initial<SEP>P1<SEP>1 10.0
# Dwise1<SEP>stride<SEP>P2<SEP>1 7
# Dwise1<SEP>initial<SEP>P2<SEP>1 7.0
# Dwise1<SEP>n_iterations<SEP>2 1.0
# Dwise1<SEP>lower_iterations<SEP>2 0
# Dwise1<SEP>stride<SEP>Q1<SEP>2 7
# Dwise1<SEP>initial<SEP>Q1<SEP>2 10.0
# Dwise1<SEP>stride<SEP>Q2<SEP>2 7
# Dwise1<SEP>initial<SEP>Q2<SEP>2 7.0
# Dwise1<SEP>n_iterations<SEP>3 960.0
# Dwise1<SEP>lower_iterations<SEP>3 959
# Dwise1<SEP>stride<SEP>T1<SEP>3 1
# Dwise1<SEP>initial<SEP>T1<SEP>3 1
# Dwise1<SEP>n_iterations<SEP>4 1.0
# Dwise1<SEP>lower_iterations<SEP>4 0.0
# Dwise1<SEP>stride<SEP>P1<SEP>4 7
# Dwise1<SEP>initial<SEP>P1<SEP>4 10.0
# Dwise1<SEP>stride<SEP>P2<SEP>4 7
# Dwise1<SEP>initial<SEP>P2<SEP>4 7.0
# Dwise1<SEP>n_iterations<SEP>5 1.0
# Dwise1<SEP>lower_iterations<SEP>5 0.0
# Dwise1<SEP>stride<SEP>Q1<SEP>5 7
# Dwise1<SEP>initial<SEP>Q1<SEP>5 10.0
# Dwise1<SEP>stride<SEP>Q2<SEP>5 7
# Dwise1<SEP>initial<SEP>Q2<SEP>5 7.0
# Dwise1<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WAB1'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# Dwise1<SEP>first_latency<SEP>MAC<SEP>18 0.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>4 0.0
# Dwise1<SEP>stride<SEP>Q1<SEP>1 0
# Dwise1<SEP>initial<SEP>Q1<SEP>1 0.0
# Dwise1<SEP>stride<SEP>Q2<SEP>1 0
# Dwise1<SEP>initial<SEP>Q2<SEP>1 0.0
# Dwise1<SEP>stride<SEP>P1<SEP>2 0
# Dwise1<SEP>initial<SEP>P1<SEP>2 0.0
# Dwise1<SEP>stride<SEP>P2<SEP>2 0
# Dwise1<SEP>initial<SEP>P2<SEP>2 0.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>7 0.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>9 0.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>16 0.0
# Dwise1<SEP>first_latency<SEP>MAC<SEP>6 0.0
# PwiseB2<SEP>stride0 7
# PwiseB2<SEP>stride1 7
# PwiseB2<SEP>stride2 960
# PwiseB2<SEP>stride3 1.0
# PwiseB2<SEP>stride4 7.0
# PwiseB2<SEP>stride5 7.0
# PwiseB2<SEP>latency<SEP>compute 0.0150528
# PwiseB2<SEP>first_latency<SEP>MAC<SEP>13 15680.0
# PwiseB2<SEP>latency<SEP>GlobalBuffer 0
# PwiseB2<SEP>latency<SEP>MainMemory 0
# PwiseB2<SEP>energy<SEP>GlobalBuffer<SEP>read 0
# PwiseB2<SEP>energy<SEP>GlobalBuffer<SEP>write 0
# PwiseB2<SEP>energy<SEP>MainMemory<SEP>read 307200.0
# PwiseB2<SEP>energy<SEP>MainMemory<SEP>write 15680.0
# PwiseB2<SEP>energy<SEP>MAC<SEP>compute 0
# PwiseB2<SEP>energy<SEP>MainMemory<SEP>leak 0
# PwiseB2<SEP>energy<SEP>GlobalBuffer<SEP>leak 0
# PwiseB2<SEP>energy<SEP>MAC<SEP>leak 0
# PwiseB2<SEP>n_iterations<SEP>0 1.0
# PwiseB2<SEP>lower_iterations<SEP>0 0
# PwiseB2<SEP>stride<SEP>P2<SEP>0 7
# PwiseB2<SEP>initial<SEP>P2<SEP>0 7
# PwiseB2<SEP>n_iterations<SEP>1 1.0
# PwiseB2<SEP>lower_iterations<SEP>1 0
# PwiseB2<SEP>stride<SEP>Q2<SEP>1 7
# PwiseB2<SEP>initial<SEP>Q2<SEP>1 7
# PwiseB2<SEP>n_iterations<SEP>2 1.0
# PwiseB2<SEP>lower_iterations<SEP>2 0
# PwiseB2<SEP>stride<SEP>T1<SEP>2 960
# PwiseB2<SEP>initial<SEP>T1<SEP>2 960
# PwiseB2<SEP>n_iterations<SEP>3 960.0
# PwiseB2<SEP>lower_iterations<SEP>3 959.0
# PwiseB2<SEP>stride<SEP>T1<SEP>3 1
# PwiseB2<SEP>initial<SEP>T1<SEP>3 1.0
# PwiseB2<SEP>n_iterations<SEP>4 1.0
# PwiseB2<SEP>lower_iterations<SEP>4 0.0
# PwiseB2<SEP>stride<SEP>P2<SEP>4 7
# PwiseB2<SEP>initial<SEP>P2<SEP>4 7.0
# PwiseB2<SEP>n_iterations<SEP>5 1.0
# PwiseB2<SEP>lower_iterations<SEP>5 0.0
# PwiseB2<SEP>stride<SEP>Q2<SEP>5 7
# PwiseB2<SEP>initial<SEP>Q2<SEP>5 7.0
# PwiseB2<SEP>mapping type=None nodes=[Storage(type=None, tensors=['WB1'], component='MainMemory', component_object=Memory(type=None, name='MainMemory', attributes=MemoryAttributes(type=None, global_cycle_period=1e-09, n_instances=1, energy_scale=1, area_scale=1, energy=None, area=None, datawidth={'All()': 1}, bandwidth_reads_plus_writes_per_cycle=inf, bandwidth_reads_per_cycle=inf, bandwidth_writes_per_cycle=inf, size=inf, version='0.5', spec={'type': None, 'arch': {'type': None, 'nodes': [{'type': None, 'name': 'MainMemory', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': '~Intermediates()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 1, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'GlobalBuffer', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'datawidth': {'All()': 1}, 'bandwidth_reads_plus_writes_per_cycle': inf, 'bandwidth_reads_per_cycle': inf, 'bandwidth_writes_per_cycle': inf, 'size': 'inf'}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}, 'spatial': [], 'temporal': {'type': None, 'version': '0.5', 'reuse': 'All', 'loop_bounds': [], 'rmw_first_update': []}, 'tensors': {'type': None, 'bypass': '~All', 'keep': 'All()', 'tile_shape': [], 'no_refetch_from_above': '~All'}, 'dataflow': {'type': None, 'tensor_order_options': []}}, 'component_class': None, 'actions': [{'type': None, 'name': 'read', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'write', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None, 'bits_per_action': 1}}]}, {'type': None, 'name': 'MAC', 'attributes': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': None, 'area': None, 'computes_per_cycle': 1}, 'spatial': [], 'constraints': {'type': None, 'name': None, 'misc': {'type': None, 'enabled': True}}, 'component_class': None, 'actions': [{'type': None, 'name': 'compute', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}, {'type': None, 'name': 'leak', 'arguments': {'type': None, 'global_cycle_period': 'REQUIRED', 'n_instances': 1, 'energy_scale': 1, 'area_scale': 1, 'energy': 0, 'area': None}}]}], 'version': '0.5', 'global_cycle_period': 1e-09}, 'c ...
# PwiseB2<SEP>stride<SEP>P2<SEP>3 0
# PwiseB2<SEP>initial<SEP>P2<SEP>3 0.0
# PwiseB2<SEP>stride<SEP>Q2<SEP>4 0
# PwiseB2<SEP>initial<SEP>Q2<SEP>4 0.0
# PwiseB2<SEP>stride<SEP>T1<SEP>5 0
# PwiseB2<SEP>initial<SEP>T1<SEP>5 0.0
# PwiseB2<SEP>first_latency<SEP>MAC<SEP>10 0.0
# PwiseB2<SEP>first_latency<SEP>MAC<SEP>6 0.0
# PwiseB2<SEP>first_latency<SEP>MAC<SEP>9 0.0
# Total<SEP>mapping <fastfusion.mapper.FFM.main.MappingFromRow object at 0x721c6fa1ff80>
